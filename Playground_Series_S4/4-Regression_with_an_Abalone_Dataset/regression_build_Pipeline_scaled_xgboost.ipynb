# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
import optuna
import joblib
import shap
from pandas.api.types import is_string_dtype
from pandas.api.types import is_numeric_dtype

# STATISTICS
from statsmodels.graphics.gofplots import qqplot

# HYPOTHESIS TESTING
from scipy.stats import ks_2samp, normaltest, boxcox, yeojohnson, shapiro
from scipy.cluster import hierarchy
from scipy.cluster.hierarchy import dendrogram, linkage
from scipy.spatial.distance import squareform

# Sklearn preprocessing
from sklearn.impute import KNNImputer
from sklearn.model_selection import cross_val_score, KFold, RandomizedSearchCV, train_test_split, GridSearchCV, StratifiedKFold, StratifiedShuffleSplit
from sklearn.preprocessing import MinMaxScaler, StandardScaler, RobustScaler, OneHotEncoder, PolynomialFeatures
from sklearn.pipeline import Pipeline, FeatureUnion
from sklearn.compose import ColumnTransformer
from sklearn.svm import SVR
from sklearn.linear_model import LinearRegression, Lasso, Ridge, ElasticNet
from sklearn.ensemble import AdaBoostRegressor,StackingRegressor,RandomForestRegressor, GradientBoostingRegressor, VotingRegressor, HistGradientBoostingRegressor, ExtraTreesRegressor
from sklearn.metrics import make_scorer, mean_squared_error, mean_squared_log_error
from sklearn.feature_selection import SelectKBest, f_regression, mutual_info_regression
from sklearn.inspection import permutation_importance
from xgboost import XGBRegressor
from lightgbm import LGBMRegressor
from catboost import CatBoostRegressor
from sklearn.neighbors import KNeighborsRegressor, NearestNeighbors
from sklearn.kernel_approximation import Nystroem
from sklearn.model_selection import cross_validate
from sklearn.linear_model import Ridge
from sklearn.preprocessing import PolynomialFeatures
from sklearn.compose import TransformedTargetRegressor
from sklearn.pipeline import make_pipeline
from sklearn.feature_selection import RFECV
from sklearn.preprocessing import PowerTransformer
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import PowerTransformer, FunctionTransformer, StandardScaler


pd.set_option('display.max_rows', 100)
pd.set_option('display.max_columns', 100)
warnings.filterwarnings("ignore", category=UserWarning)

SEED = 42

# %%
# Load data
train = pd.read_csv('data/train.csv',index_col=0)
test = pd.read_csv('data/test.csv',index_col=0)
sub = pd.read_csv('data/sample_submission.csv',index_col=0)

# %% [markdown]
# # Understanding Abalone Dataset Features
#
# - Sex: This feature represents the gender of the abalone,categorized as male (M), female (F), or infant (I).
#
# - Length: The length feature denotes the longest measurement of the abalone shell, from the apex to the base, measured in millimeters.
#
# - Diameter: Diameter represents the measurement of the abalone shell perpendicular to its length, also measured in millimeters.
#
# - Height: This feature signifies the height of the abalone shell, measured perpendicular to the plane formed by the length and diameter, in millimeters.
#
# - Whole weight: Whole weight indicates the total weight of the abalone, encompassing both the meat and the shell, measured in grams.
#
# - Whole weight.1 (Shucked weight): This feature represents the weight of the abalone meat only, measured in grams. It indicates the amount of meat extracted from the shell.
#
# - Whole weight.2 (Viscera weight): Viscera weight signifies the weight of the abalone gut after bleeding, measured in grams.It provides insights into the weight of the internal organs of the abalone.
#
# - Shell weight: This feature represents the weight of the abalone shell only, excluding the meat, measured in grams. It provides insights into the weight distribution between the shell and the edible portion of the abalone.
#
# - Rings: Rings signify the number of rings present on the abalone shell, serving as an indicator of the abalone's age.

# %%
def rename_and_lowercase(df):
    """Rename columns and convert them to lowercase"""
    df = df.rename(columns = {'Whole weight.1':'shucked weight'})
    df = df.rename(columns = {'Whole weight.2':'viscera weight'})
    df = df.rename(columns=lambda x: x.lower().replace(' ', '_'))
    return df

train = rename_and_lowercase(train)
test = rename_and_lowercase(test)

train.columns, test.columns
# Out:
# (Index(['sex', 'length', 'diameter', 'height', 'whole_weight', 'shucked_weight',
#         'viscera_weight', 'shell_weight', 'rings'],
#        dtype='object'),
#  Index(['sex', 'length', 'diameter', 'height', 'whole_weight', 'shucked_weight',
#         'viscera_weight', 'shell_weight'],
#        dtype='object'))

# %% [markdown]
# # 1 - EDA - Exploratory Analysis

# %% [markdown]
# ## 1.1 - Summary Statistics

# %%
def generate_summary_statistics(data):
  
    summary_table = pd.DataFrame(data.dtypes, columns=['dtypes'])
    summary_table['Missing'] = data.isnull().sum()
    summary_table['Unique'] = data.nunique()
    summary_table['Count'] = data.count()
    summary_table['Duplicated'] = data.duplicated().sum()
    summary_table['zero_values'] = data.isin([0]).sum()
    
    
    return summary_table

# %%
generate_summary_statistics(train)
# Out:
#                  dtypes  Missing  Unique  Count  Duplicated  zero_values
# sex              object        0       3  90615           0            0
# length          float64        0     157  90615           0            0
# diameter        float64        0     126  90615           0            0
# height          float64        0      90  90615           0            6
# whole_weight    float64        0    3175  90615           0            0
# shucked_weight  float64        0    1799  90615           0            0
# viscera_weight  float64        0     979  90615           0            0
# shell_weight    float64        0    1129  90615           0            0
# rings             int64        0      28  90615           0            0

# %%
generate_summary_statistics(test)
# Out:
#                  dtypes  Missing  Unique  Count  Duplicated  zero_values
# sex              object        0       3  60411           0            0
# length          float64        0     148  60411           0            0
# diameter        float64        0     130  60411           0            0
# height          float64        0      85  60411           0            2
# whole_weight    float64        0    3037  60411           0            0
# shucked_weight  float64        0    1747  60411           0            0
# viscera_weight  float64        0     960  60411           0            0
# shell_weight    float64        0    1089  60411           0            0

# %% [markdown]
# <div style="background-color: #343A1A; padding: 10px; border: 1px solid #ccc; border-radius: 5px;">
#     <p>There are missing values in the dataset. The column <b>height</b> .</p>
# <div>

# %% [markdown]
# ## 1.2 - Univariate Analysis

# %%
# function to calculate univariate stats like pandas describe method
def univariate_stats(df):
    
    output_df = pd.DataFrame(columns=['Count', 'Missing', 'Unique', 'Dtype', 'IsNumeric', 'Mode', 'Mean', 'Min', '25%', 'Median', '75%', 'Max', 'Std', 'Skew', 'Kurt'])
    
    for col in df:
        if is_numeric_dtype(df[col]):
            output_df.loc[col] = [df[col].count(), df[col].isnull().sum(), df[col].nunique(), df[col].dtype, is_numeric_dtype(df[col]), df[col].mode().values[0], df[col].mean(), df[col].min(), df[col].quantile(.25), df[col].median(), df[col].quantile(.75), df[col].max(), df[col].std(), df[col].skew(), df[col].kurt() ]
        else:
            output_df.loc[col] = [df[col].count(), df[col].isnull().sum(), df[col].nunique(), df[col].dtype, is_numeric_dtype(df[col]), df[col].mode().values[0], '-', '-', '-', '-', '-', '-', '-', '-', '-' ]
    
    return output_df.sort_values(by=['IsNumeric', 'Unique'], ascending=False)

# %%
univariate_stats(train)
# Out:
#                 Count  Missing  Unique    Dtype  IsNumeric    Mode      Mean  \
# whole_weight    90615        0    3175  float64       True  0.5805  0.789035
# shucked_weight  90615        0    1799  float64       True   0.096  0.340778
# shell_weight    90615        0    1129  float64       True    0.24  0.225898
# viscera_weight  90615        0     979  float64       True  0.1715  0.169422
# length          90615        0     157  float64       True   0.575  0.517098
# diameter        90615        0     126  float64       True    0.45  0.401679
# height          90615        0      90  float64       True    0.15  0.135464
# rings           90615        0      28    int64       True       9  9.696794
# sex             90615        0       3   object      False       I         -
#
#                    Min     25%  Median     75%     Max       Std      Skew  \
# whole_weight     0.002   0.419  0.7995  1.0675  2.8255  0.457671  0.429316
# shucked_weight   0.001  0.1775    0.33   0.463   1.488  0.204428  0.591973
# shell_weight    0.0015    0.12   0.225   0.305   1.005  0.130203  0.479092
# viscera_weight  0.0005  0.0865   0.166  0.2325    0.76  0.100909  0.476733
# length           0.075   0.445   0.545     0.6   0.815  0.118217 -0.732015
# diameter         0.055   0.345   0.425    0.47    0.65  0.098026 -0.695236
# height             0.0    0.11    0.14    0.16    1.13  0.038008  0.309975
# rings                1     8.0     9.0    11.0      29  3.176221  1.204273
# sex                  -       -       -       -       -         -         -
#
#                      Kurt
# whole_weight    -0.185136
# shucked_weight   0.284012
# shell_weight     0.096049
# viscera_weight  -0.203721
# length           0.133364
# diameter         0.000646
# height          13.454051
# rings            2.612934
# sex                     -

# %% [markdown]
# **Note** : height has some null values

# %%
univariate_stats(test)
# Out:
#                 Count  Missing  Unique    Dtype  IsNumeric    Mode      Mean  \
# whole_weight    60411        0    3037  float64       True  0.5805  0.790062
# shucked_weight  60411        0    1747  float64       True  0.3485  0.341227
# shell_weight    60411        0    1089  float64       True    0.24  0.226125
# viscera_weight  60411        0     960  float64       True  0.1715  0.169419
# length          60411        0     148  float64       True   0.575  0.517428
# diameter        60411        0     130  float64       True    0.45  0.401961
# height          60411        0      85  float64       True    0.15  0.135751
# sex             60411        0       3   object      False       I         -
#
#                    Min     25%  Median     75%     Max       Std      Skew  \
# whole_weight     0.002  0.4195  0.8015    1.07  2.8255  0.457591  0.435664
# shucked_weight   0.001  0.1785   0.329  0.4645   1.488  0.204221  0.593206
# shell_weight    0.0015    0.12   0.225   0.305   1.004  0.129826  0.468524
# viscera_weight  0.0005  0.0865   0.166  0.2325  0.6415   0.10072  0.476129
# length           0.075    0.45   0.545     0.6     0.8  0.117609 -0.734565
# diameter         0.055   0.345   0.425    0.47    0.65   0.09747 -0.696312
# height             0.0    0.11    0.14    0.16   1.095  0.038175  0.554506
# sex                  -       -       -       -       -         -         -
#
#                      Kurt
# whole_weight    -0.165426
# shucked_weight   0.290172
# shell_weight     0.042671
# viscera_weight  -0.204883
# length           0.141789
# diameter         0.004065
# height          17.693333
# sex                     -

# %%
# list of numerical and categorical columns

numeric_cols = train.select_dtypes(exclude=['object']).columns.tolist()
categorical_cols = train.select_dtypes(include=['object']).columns.tolist()
target = 'rings'
numeric_cols_without_target = [col for col in numeric_cols if col != target]

numeric_cols, categorical_cols, numeric_cols_without_target
# Out:
# (['length',
#   'diameter',
#   'height',
#   'whole_weight',
#   'shucked_weight',
#   'viscera_weight',
#   'shell_weight',
#   'rings'],
#  ['sex'],
#  ['length',
#   'diameter',
#   'height',
#   'whole_weight',
#   'shucked_weight',
#   'viscera_weight',
#   'shell_weight'])

# %% [markdown]
# ### Histograms

# %%
def plot_histograms(df_train, df_test, target_col, n_cols=3):
    n_rows = (len(df_train.columns) - 1) // n_cols + 1

    fig, axes = plt.subplots(n_rows, n_cols, figsize=(18, 4 * n_rows))

    axes = axes.flatten()

    for i, var_name in enumerate(df_train.columns.tolist()):
        
        if var_name != target_col:
            ax = axes[i]
       
            # plot histogram for each variable in train
            sns.histplot(df_train[var_name], kde=True, ax=ax, label='train')

            # plot histogram for each variable in test
            sns.histplot(df_test[var_name], kde=True, ax=ax, label='test')

        
        ax.set_title(f'{var_name} Distribution (Train vs Test)')
        ax.legend()

    plt.tight_layout()
    plt.show()

plot_histograms(train[numeric_cols], test, target, n_cols=3)

# %% [markdown]
# ### Distributions

# %%
def plot_distributions(df, hue, title='', drop_cols=[]):
    
    cols = df.columns.drop([hue] + drop_cols)
    n_cols = 2
    n_rows = (len(cols) - 1) // n_cols + 1
    
    fig, axes = plt.subplots(n_rows, n_cols, figsize=(14, 4 * n_rows))
    
    for i, var_name in enumerate(cols):
        row = i // n_cols
        col = i % n_cols
        
        ax = axes[row, col]
        sns.histplot(df, x=var_name, hue=hue, kde=True, ax=ax)
        ax.set_title(f'{var_name} Distribution')
    
    fig.suptitle(f'{title} Distribution Plot by {hue}', fontweight='bold', fontsize=16)
    plt.tight_layout()
    plt.show()
    
plot_distributions(train,hue='sex', title='Train data')
plot_distributions(test,hue='sex', title='Test data')

# %% [markdown]
# <div style="background-color: #343A1A; padding: 10px; border: 1px solid #ccc; border-radius: 5px;">
#
# **Note:**
# <ul>
#     <li>There is a big difference in distribution between I (infant) and adults (M or F). It almost like a binary variable, either is is infant or not</li>
#     <li>Maybe test it feature engineering</li>
# </ul>
#
# </div>

# %% [markdown]
# ### Correlations

# %%
def plot_heatmap(df,title):
    
    mask = np.zeros_like(df.astype(float).corr())
    mask[np.triu_indices_from(mask)] = True
    
    plt.figure(figsize=(10, 8))
    
    plt.title(f'{title} Correlation of Features', fontweight='bold', y=1.02, size=20)
    
    sns.heatmap(df.astype(float).corr(),
                linewidths=0.1,
                vmax=1.0, 
                square=True, 
                cmap='coolwarm', 
                linecolor='white', 
                annot=True, 
                mask=mask)
    
plot_heatmap(train[numeric_cols], title='Train data')
plot_heatmap(test[numeric_cols_without_target], title='Test data')

# %% [markdown]
# <div style="background-color: #343A1A; padding: 10px; border: 1px solid #ccc; border-radius: 5px;">
#
# **Notes**
#
# <p>When all features are highly correlated, it can lead to multicollinearity in your model, which can make the model's estimates very sensitive to changes in the model. Here are a few strategies to handle this situation</p>
#
# <ul>
#     <li><b>Feature Selection:</b> You can manually select a subset of your features based on domain knowledge or based on the correlation matrix</li>
#     <li><b>Dimensionality Reduction:</b> Techniques like Principal Component Analysis (PCA) can be used to reduce the dimensionality of your data. PCA creates new uncorrelated variables that successively maximize variance</li>
#     <li><b>Regularization:</b> Use a model that includes a penalty term for complexity in the loss function, such as Lasso or Ridge regression. These models can help to avoid overfitting by penalizing large coefficients</li>
#     <li><b>Variance Inflation Factor (VIF):</b> Calculate the VIF for each variable, which measures how much the variance of the estimated regression coefficients are increased because of multicollinearity. If VIF is high for a variable, consider dropping it</li>
#     <li><b>Combine Features:</b> If it makes sense in the context of your problem, you can combine correlated features into a single feature (for example, by taking an average)</li>
# </ul>
#
# </div>

# %% [markdown]
# ### Hierarchical Clustering

# %%
def hierarchical_clustering(data, title, drop_cols=[]):
    
    data = data.drop(drop_cols, axis=1, errors='ignore')
    
    fig, axis = plt.subplots(1,1,figsize=(10, 8),dpi=100)
    correlations = data.corr()
    coverted_corr = 1 - np.abs(correlations)
    Z = linkage(squareform(coverted_corr), method='complete')
    
    dn = dendrogram(Z, labels=data.columns, ax=axis, above_threshold_color='#ff0000', leaf_font_size=10) 
    hierarchy.set_link_color_palette(None)
    plt.grid(axis='x')
    plt.title(f'{title} Hierarchical clustering, Dendrogram', fontsize=18, fontweight='bold')
    plt.show()
    
hierarchical_clustering(train[numeric_cols], title='Train data', drop_cols='rings')
hierarchical_clustering(test[numeric_cols_without_target], title='Test data')

# %% [markdown]
# <div style="background-color: #343A1A; padding: 10px; border: 1px solid #ccc; border-radius: 5px;">
#
# **Notes**
#
# <p>A dendrogram is a diagram that shows the hierarchical relationship between objects. It is most commonly created as an output from hierarchical clustering. The main use of a dendrogram is to work out the best way to allocate objects to clusters</p>
#
# <p>Observations are allocated to clusters by drawing a horizontal line through the dendrogram. Observations that are joined together below the line are in clusters</p>
#
# <p>In the case, seems we have two clusters</p>
# <ul>
#     <li><b>weight cluster</b> -> shell + schuked + whole + viscera</li>
#     <li><b>dimensions cluster</b> -> height + lenght + diameter</li>
# <ul>
#
# </div>

# %% [markdown]
# ###  QQplots

# %%
def plot_qqplot(df, title, drop_cols=[]):
    
    df = df.drop(drop_cols, axis=1, errors='ignore')
    
    fig, axes = plt.subplots(1, len(df.columns), figsize=(20, 5))
    
    for i, col in enumerate(df.columns):
        qqplot(df[col], line='s', ax=axes[i])
        axes[i].set_title(f'{col} QQ Plot')
    
    fig.suptitle(f'{title} QQ Plot', fontweight='bold', fontsize=20)
    plt.tight_layout()
    plt.show()
    
plot_qqplot(train[numeric_cols], title='Train data', drop_cols='rings')
plot_qqplot(test[numeric_cols_without_target], title='Test data')

# %% [markdown]
# ### Normality check

# %%
def normality_test(data, alpha=0.05):
    stat = None
    for col in data.columns:
        _, p = normaltest(data[col].dropna())
        if p > alpha:
            print(f'{col} is normally distributed')
        else:
            print(f'{col} is not normally distributed')

                
normality_test(train[numeric_cols])
normality_test(test[numeric_cols_without_target])
# Out:
# length is not normally distributed
# diameter is not normally distributed
# height is not normally distributed
# whole_weight is not normally distributed
# shucked_weight is not normally distributed
# viscera_weight is not normally distributed
# shell_weight is not normally distributed
# rings is not normally distributed
# length is not normally distributed
# diameter is not normally distributed
# height is not normally distributed
# whole_weight is not normally distributed
# shucked_weight is not normally distributed
# viscera_weight is not normally distributed
# shell_weight is not normally distributed

# %% [markdown]
# <div style="background-color: #343A1A; padding: 10px; border: 1px solid #ccc; border-radius: 5px;">
#
# **Notes**
#
# <p>If the distribution of your data is not normal, there are several strategies you can use to transform your data to be more normally distributed:</p>
# <div>
# <ul>
# <li><b>Log Transformation:</b> This is useful when your data is skewed. It can help to reduce the skewness.</li>
# <pre>
# <code>
# df['log_transformed'] = np.log(df['original_column'])
# </code>
# </pre>
# <li><b>Square Root Transformation:</b> This is another method to reduce skewness. It's less strong than the log transformation.</li>
# <pre>
# <code>
# df['sqrt_transformed'] = np.sqrt(df['original_column'])
# </code>
# </pre>
#
#
# <li><b>Box-Cox Transformation:</b> This is a parametric transformation method that seeks the best power transformation of the data that reduces skewness.</li>
# <pre>
# <code>
# df['boxcox_transformed'], _ = stats.boxcox(df['original_column'])
# </code>
# </pre>
#
# <li><b>Yeo-Johnson Transformation:</b> This is similar to Box-Cox, but it can be used with zero and negative values.</li>
# <pre>
# <code>
# df['yeojohnson_transformed'], _ = stats.yeojohnson(df['original_column'])
# </code>
# </pre>
# <ul>
# </div>
# </div>

# %%
# visualize feature distribution vs log feature distribution side by side 
def plot_log_transform(data, title, drop_cols=[]):
    
    data = data.drop(drop_cols, axis=1, errors='ignore')
    
    fig, axes = plt.subplots(1, len(data.columns), figsize=(20, 5))
    
    for i, col in enumerate(data.columns):
        sns.histplot(data[col], kde=True, ax=axes[i], label='Original')
        sns.histplot(np.log1p(data[col]), kde=True, ax=axes[i], label='Log')
        axes[i].set_title(f'{col} Distribution')
        axes[i].legend()
    
    fig.suptitle(f'{title} Distribution vs Log Distribution', fontweight='bold', fontsize=20)
    plt.tight_layout()
    plt.show()
    
plot_log_transform(train[numeric_cols], title='Train data', drop_cols='rings')
plot_log_transform(test[numeric_cols_without_target], title='Test data')

# %%
# visualize feature distribution vs squared root feature distribution side by side
def plot_sqrt_transform(data, title, drop_cols=[]):
    
    data = data.drop(drop_cols, axis=1, errors='ignore')
    
    fig, axes = plt.subplots(1, len(data.columns), figsize=(20, 5))
    
    for i, col in enumerate(data.columns):
        sns.histplot(data[col], kde=True, ax=axes[i], label='Original')
        sns.histplot(np.sqrt(data[col]), kde=True, ax=axes[i], label='Square Root')
        axes[i].set_title(f'{col} Distribution')
        axes[i].legend()
    
    fig.suptitle(f'{title} Distribution vs Square Root Distribution', fontweight='bold', fontsize=20)
    plt.tight_layout()
    plt.show()
    
plot_sqrt_transform(train[numeric_cols], title='Train data', drop_cols='rings')
plot_sqrt_transform(test[numeric_cols_without_target], title='Test data')

# %%
# visualize feature distribution vs box-cox transformation to features distribution side by side
def plot_boxcox_transform(data, title, drop_cols=[]):
    
    data = data.drop(drop_cols, axis=1, errors='ignore')
    
    fig, axes = plt.subplots(1, len(data.columns), figsize=(20, 5))
    
    for i, col in enumerate(data.columns):
        sns.histplot(data[col], kde=True, ax=axes[i], label='Original')
        sns.histplot(boxcox(data[col] + 1)[0], kde=True, ax=axes[i], label='Box-Cox')
        axes[i].set_title(f'{col} Distribution')
        axes[i].legend()
    
    fig.suptitle(f'{title} Distribution vs Box-Cox Distribution', fontweight='bold', fontsize=20)
    plt.tight_layout()
    plt.show()
    
plot_boxcox_transform(train[numeric_cols], title='Train data', drop_cols='rings')
plot_boxcox_transform(test[numeric_cols_without_target], title='Test data')

# %%
# visualize feature distribution vs yeo-johnson transformation to features distribution side by side:
def plot_yeojohnson_transform(data, title, drop_cols=[]):
    
    data = data.drop(drop_cols, axis=1, errors='ignore')
    
    fig, axes = plt.subplots(1, len(data.columns), figsize=(20, 5))
    
    for i, col in enumerate(data.columns):
        sns.histplot(data[col], kde=True, ax=axes[i], label='Original')
        sns.histplot(yeojohnson(data[col])[0], kde=True, ax=axes[i], label='Yeo-Johnson')
        axes[i].set_title(f'{col} Distribution')
        axes[i].legend()
    
    fig.suptitle(f'{title} Distribution vs Yeo-Johnson Distribution', fontweight='bold', fontsize=20)
    plt.tight_layout()
    plt.show()
    
plot_yeojohnson_transform(train[numeric_cols], title='Train data', drop_cols='rings')
plot_yeojohnson_transform(test[numeric_cols_without_target], title='Test data')

# %% [markdown]
# <div style="background-color: #343A1A; padding: 10px; border: 1px solid #ccc; border-radius: 5px;">
#
# **Notes**
#
# <p>Visual Inspection Conclusions</p>
# <ul>
#     <li><b>Normal Distribuition:</b> Height</li>
#     <li><b>Yeo-Johnson Transformation:</b> Length, Diameter</li>
#     <li><b>Sqrt Transformation:</b> whole_weight, shucked_weight, viscera_weight, shell_weight</li>
# <ul>

# %%
# Violinplot sex and rings by sex
sns.violinplot(data=train, y=train['rings'], hue='sex');

# %%
# Target variable distribution
fig, axes = plt.subplots(1, 2, figsize=(15, 5))
sns.histplot(data=train, x='rings', kde=True, bins=30,hue='sex',ax=axes[0])
sns.histplot(data=train, x=np.log1p(train['rings']), kde=True, bins=30,hue='sex', ax=axes[1])
axes[0].set_title('Rings Distribution')
axes[1].set_title('Log Rings Distribution')
plt.show()

# %% [markdown]
# <div style="background-color: #343A1A; padding: 10px; border: 1px solid #ccc; border-radius: 5px;">
#
# **Notes**
# <ul>
#     <li>
#         <p>Initially target distribution is skewed, with log transformation looks better</p>
#     </li>
# </ul>
# </div>

# %% [markdown]
# ### PairPlot

# %%
#sns.pairplot(data=train, vars=numeric_cols, hue='sex', diag_kind='kde', corner=True);

# %% [markdown]
# <div style="background-color: #343A1A; padding: 10px; border: 1px solid #ccc; border-radius: 5px;">
#
# <p>Inferences</p>
#
# <ol>
# <li>There is a bit diference between an infant and adult Abalone</li>
# <li>
# <p>Linear relations:</p>
# <ul>length vs diameter - (+++)  - </ul>
# <ul>height vs length and diameter - (+) </ul>
# <ul>between weights - (+++) with dispersion </ul>
# <li>
# <p>Polinomial relations</p>
# <ul>all weights vs length - poly2, exp</ul>
# <ul>all weights vs diameter - pol2, exp </ul>
# </li>
# <li>Sex is an important feature to destinguist between infant and adult</li>
# <ol>
#
# <div>

# %% [markdown]
# # 2 - Feature Engineering

# %%
#feature creation transformer

class FeatureCreation:
    def __init__(self, columns):
        self.columns = columns

    def fit(self, X, y=None):
        return self

    def transform(self, X):
        X = X.copy()
        X['length_diameter_ratio'] = X['length'] / X['diameter']
        X['height_diameter_ratio'] = X['height'] / X['diameter']
        X['volume'] = (4/3) * np.pi * (X['length']/2) * (X['diameter']/2) * (X['height']/2)
        X['shell_thickness_to_length'] = (X['whole_weight'] - X['shucked_weight']) / X['length']
        X['shell_thickness_to_diameter'] = (X['whole_weight'] - X['shucked_weight']) / X['diameter']
        X['length_diameter_interact'] = X['length'] * X['diameter']
        X['whole_shell_weight_interact'] = X['whole_weight'] * X['shell_weight']
        X['length_squared'] = X['length'] ** 2
        X['diameter_cubed'] = X['diameter'] ** 3
        return X

# %% [markdown]
# # 3 - Pipelines

# %%
#Normal Distribution: Height - do not need to change
#Yeo-Johnson Transformation: Length, Diameter
#Sqrt Transformation: whole_weight, shucked_weight, viscera_weight, shell_weight

# Define the columns to apply the transformations
#numeric_cols_without_target = ['length','diameter','height','whole_weight','shucked_weight','viscera_weight','shell_weight']
yeo_johnson_columns = ['length', 'diameter']
sqrt_columns = ['whole_weight', 'shucked_weight', 'viscera_weight', 'shell_weight']
normal_columns = ['height']


X = train.drop(columns='rings')
y = train['rings']

power_transformer = Pipeline(steps=[
    ('power', PowerTransformer(method='yeo-johnson')),
    ('scaler', StandardScaler())
    ])


sqrt_transformer = Pipeline(steps=[
    ('sqrt', FunctionTransformer(np.sqrt)),
    ('scaler', StandardScaler())
    ])

preprocessor = ColumnTransformer(
    transformers=[
        ('power_transformer', power_transformer, yeo_johnson_columns),
        ('sqrt_transformer', sqrt_transformer, sqrt_columns),
        ('scaler_height', StandardScaler(), normal_columns),
        ('encoder_sex', OneHotEncoder(drop='first',handle_unknown='ignore'), categorical_cols)
    ])


# Create a recursive feature eliminator
rfe = RFECV(
    estimator=XGBRegressor(random_state=SEED), 
    step=1, 
    cv=5, 
    scoring='neg_mean_squared_log_error',
    min_features_to_select=1,
    verbose=1,
    n_jobs=-1)

# Create a pipeline with preprocessing and RFE
rfe_pipe = Pipeline([
    ('preprocessor', preprocessor),
    ('rfe', rfe),
])

rfe_pipe
# Out:
# Pipeline(steps=[('preprocessor',
#                  ColumnTransformer(transformers=[('power_transformer',
#                                                   Pipeline(steps=[('power',
#                                                                    PowerTransformer()),
#                                                                   ('scaler',
#                                                                    StandardScaler())]),
#                                                   ['length', 'diameter']),
#                                                  ('sqrt_transformer',
#                                                   Pipeline(steps=[('sqrt',
#                                                                    FunctionTransformer(func=<ufunc 'sqrt'>)),
#                                                                   ('scaler',
#                                                                    StandardScaler())]),
#                                                   ['whole_weight',
#                                                    'shucked_weight',
#                                                    'viscera_weight',
#                                                    's...
#                                               interaction_constraints=None,
#                                               learning_rate=None, max_bin=None,
#                                               max_cat_threshold=None,
#                                               max_cat_to_onehot=None,
#                                               max_delta_step=None,
#                                               max_depth=None, max_leaves=None,
#                                               min_child_weight=None,
#                                               missing=nan,
#                                               monotone_constraints=None,
#                                               multi_strategy=None,
#                                               n_estimators=None, n_jobs=None,
#                                               num_parallel_tree=None,
#                                               random_state=42, ...),
#                        n_jobs=-1, scoring='neg_mean_squared_log_error',
#                        verbose=1))])

# %%
def objective(trial):
    
   # Define the hyperparameters to optimize
   params = {
      'n_estimators' : trial.suggest_int('n_estimators',200,5000),
      'learning_rate' : trial.suggest_float('learning_rate',0.01,1, log=True),
      'min_child_weight' : trial.suggest_int('min_child_weight',1,10),
      'max_depth' : trial.suggest_int('max_depth',1,50),
      'max_delta_step' : trial.suggest_int('max_delta_step',0,20),
      'subsample' : trial.suggest_float('subsample',0.1,1, log=True),
      'colsample_bytree' : trial.suggest_float('colsample_bytree',0.1,1, log=True),
      'colsample_bylevel' : trial.suggest_float('colsample_bylevel',0.1,1, log=True),
      'reg_lambda' : trial.suggest_float('reg_lambda',0.01,100, log=True),
      'reg_alpha' : trial.suggest_float('reg_alpha',0.01,100, log=True),
      'gamma' : trial.suggest_float('gamma',0.01,100, log=True),
      'scale_pos_weight' : trial.suggest_float('scale_pos_weight',0.01,500, log=True),
   }
   
   # Initialize XGBoost model with suggested hyperparameters
   model = XGBRegressor(**params, random_state=SEED)
   
   # Create a pipeline with preprocessing and XGBoost model
   pipe = Pipeline([
      ('preprocessor', preprocessor),
      ('model', model)
   ])
   
   cv = StratifiedKFold(n_splits=5, shuffle=True, random_state=SEED)
   
   # Calculate the cross-validated negative RMSLE score
   scores = -1 * cross_val_score(pipe,
                                 X,
                                 y,
                                 cv=cv,
                                 scoring='neg_root_mean_squared_log_error',
                                 n_jobs=-1)
   
   return scores.mean()

# %%
# %%time

# # perform hyperparameter optimization with Optuna
study = optuna.create_study(direction='minimize', study_name='xgboost_feature_scaling_rfe')
study.optimize(objective, n_trials=100)

print('\n----------------------------------------\n')
print(f'Best trial: {study.best_trial.params}')
print(f'Best score: {study.best_value}')
# Out:
# [I 2024-04-10 21:17:07,117] A new study created in memory with name: xgboost_feature_scaling_rfe
# [I 2024-04-10 21:17:33,339] Trial 0 finished with value: 0.158822780264204 and parameters: {'n_estimators': 4269, 'learning_rate': 0.5732804277146388, 'min_child_weight': 3, 'max_depth': 10, 'max_delta_step': 13, 'subsample': 0.27464310500062133, 'colsample_bytree': 0.19257632950167372, 'colsample_bylevel': 0.21654676504182716, 'reg_lambda': 2.0284141003823497, 'reg_alpha': 8.305249778828877, 'gamma': 72.84705662185442, 'scale_pos_weight': 3.818540100674909}. Best is trial 0 with value: 0.158822780264204.
# [I 2024-04-10 21:17:50,785] Trial 1 finished with value: 0.16081766721740487 and parameters: {'n_estimators': 3077, 'learning_rate': 0.8539042405923271, 'min_child_weight': 9, 'max_depth': 25, 'max_delta_step': 0, 'subsample': 0.1708509862138266, 'colsample_bytree': 0.8889914498547036, 'colsample_bylevel': 0.22522404754542819, 'reg_lambda': 84.66652055111106, 'reg_alpha': 0.12191079069890483, 'gamma': 96.18771830705697, 'scale_pos_weight': 0.033557996225661045}. Best is trial 0 with value: 0.158822780264204.
# [I 2024-04-10 21:18:24,203] Trial 2 finished with value: 0.1671825068462883 and parameters: {'n_estimators': 2084, 'learning_rate': 0.12603686815952153, 'min_child_weight': 6, 'max_depth': 35, 'max_delta_step': 18, 'subsample': 0.14541233150952634, 'colsample_bytree': 0.4622411099498916, 'colsample_bylevel': 0.41279931162537226, 'reg_lambda': 12.41175556670413, 'reg_alpha': 0.36838699897830424, 'gamma': 0.2950758199192071, 'scale_pos_weight': 4.492589642499439}. Best is trial 0 with value: 0.158822780264204.
# [I 2024-04-10 21:18:56,960] Trial 3 finished with value: 0.1759905156604586 and parameters: {'n_estimators': 2648, 'learning_rate': 0.11337425202972924, 'min_child_weight': 1, 'max_depth': 8, 'max_delta_step': 18, 'subsample': 0.12345974694355263, 'colsample_bytree': 0.7206267180847454, 'colsample_bylevel': 0.5073765047101292, 'reg_lambda': 1.0162522435151826, 'reg_alpha': 1.2489563278771765, 'gamma': 0.2618113065296344, 'scale_pos_weight': 1.4098033730876218}. Best is trial 0 with value: 0.158822780264204.
# [I 2024-04-10 21:19:29,984] Trial 4 finished with value: 0.15851544689883176 and parameters: {'n_estimators': 4990, 'learning_rate': 0.044003516223540644, 'min_child_weight': 3, 'max_depth': 3, 'max_delta_step': 9, 'subsample': 0.11607069395912066, 'colsample_bytree': 0.13539036914224484, 'colsample_bylevel': 0.17943602844617135, 'reg_lambda': 0.019457797502389032, 'reg_alpha': 39.93921411709426, 'gamma': 1.0132668813080707, 'scale_pos_weight': 1.4815070639686547}. Best is trial 4 with value: 0.15851544689883176.
# [I 2024-04-10 21:19:37,488] Trial 5 finished with value: 0.17805912905230586 and parameters: {'n_estimators': 630, 'learning_rate': 0.03568127203620528, 'min_child_weight': 7, 'max_depth': 17, 'max_delta_step': 5, 'subsample': 0.17605838948096186, 'colsample_bytree': 0.12587662260849325, 'colsample_bylevel': 0.6397025110794758, 'reg_lambda': 0.38360429739926044, 'reg_alpha': 22.66501880000325, 'gamma': 0.15220617662175379, 'scale_pos_weight': 109.11662906632993}. Best is trial 4 with value: 0.15851544689883176.
# [I 2024-04-10 21:19:58,770] Trial 6 finished with value: 0.1523292422564629 and parameters: {'n_estimators': 3756, 'learning_rate': 0.04920067120394304, 'min_child_weight': 1, 'max_depth': 31, 'max_delta_step': 7, 'subsample': 0.16735103018327047, 'colsample_bytree': 0.7063472560447321, 'colsample_bylevel': 0.2203992025429309, 'reg_lambda': 6.482898358673129, 'reg_alpha': 0.18209163084824326, 'gamma': 24.57160879386363, 'scale_pos_weight': 0.07390431416830824}. Best is trial 6 with value: 0.1523292422564629.
# [I 2024-04-10 21:20:22,586] Trial 7 finished with value: 0.15803202945202086 and parameters: {'n_estimators': 3788, 'learning_rate': 0.08269866534854176, 'min_child_weight': 7, 'max_depth': 49, 'max_delta_step': 1, 'subsample': 0.5588224169794614, 'colsample_bytree': 0.12020495309466911, 'colsample_bylevel': 0.7646043176549457, 'reg_lambda': 0.07109099916965653, 'reg_alpha': 0.045185870280372464, 'gamma': 22.128376208480454, 'scale_pos_weight': 11.809304020296175}. Best is trial 6 with value: 0.1523292422564629.
# [I 2024-04-10 21:20:38,703] Trial 8 finished with value: 0.16400493938270383 and parameters: {'n_estimators': 1733, 'learning_rate': 0.02957586163737721, 'min_child_weight': 1, 'max_depth': 9, 'max_delta_step': 8, 'subsample': 0.12484454663130452, 'colsample_bytree': 0.1614713540546618, 'colsample_bylevel': 0.11389782959052967, 'reg_lambda': 86.17796084288334, 'reg_alpha': 0.010474019508996237, 'gamma': 0.5548963891742817, 'scale_pos_weight': 1.4108334869267884}. Best is trial 6 with value: 0.1523292422564629.
. Best is trial 24 with value: 0.1498557216038073.
# [I 2024-04-10 21:46:56,299] Trial 35 finished with value: 0.1499378148881619 and parameters: {'n_estimators': 3224, 'learning_rate': 0.0210867658280751, 'min_child_weight': 3, 'max_depth': 22, 'max_delta_step': 9, 'subsample': 0.8711010078544882, 'colsample_bytree': 0.4761206522297683, 'colsample_bylevel': 0.21055213281844878, 'reg_lambda': 4.8305662422010105, 'reg_alpha': 25.09529273313902, 'gamma': 0.2780897065278045, 'scale_pos_weight': 4.335050372995527}. Best is trial 24 with value: 0.1498557216038073.
# [I 2024-04-10 21:47:30,334] Trial 36 finished with value: 0.14974468219527162 and parameters: {'n_estimators': 3256, 'learning_rate': 0.021271966599279563, 'min_child_weight': 3, 'max_depth': 22, 'max_delta_step': 9, 'subsample': 0.8420872389488394, 'colsample_bytree': 0.5028666550716805, 'colsample_bylevel': 0.2546523750954405, 'reg_lambda': 2.0240031514945964, 'reg_alpha': 33.838558600283065, 'gamma': 0.33689648492866375, 'scale_pos_weight': 4.0428552070002555}. Best is trial 36 with value: 0.14974468219527162.
# [I 2024-04-10 21:48:00,451] Trial 37 finished with value: 0.14981983749441413 and parameters: {'n_estimators': 2585, 'learning_rate': 0.02173965320827792, 'min_child_weight': 3, 'max_depth': 22, 'max_delta_step': 10, 'subsample': 0.8296613816828698, 'colsample_bytree': 0.35910726267921733, 'colsample_bylevel': 0.24421002886666754, 'reg_lambda': 1.828531809180684, 'reg_alpha': 25.338750061120592, 'gamma': 0.3780232370870604, 'scale_pos_weight': 3.319746105860172}. Best is trial 36 with value: 0.14974468219527162.
# [I 2024-04-10 21:48:13,670] Trial 38 finished with value: 0.16326315492759236 and parameters: {'n_estimators': 1753, 'learning_rate': 0.9325260012272759, 'min_child_weight': 1, 'max_depth': 13, 'max_delta_step': 9, 'subsample': 0.7888074611943381, 'colsample_bytree': 0.3347736541521426, 'colsample_bylevel': 0.331962591710328, 'reg_lambda': 0.4591706989836942, 'reg_alpha': 26.56941829329175, 'gamma': 1.4376459982142666, 'scale_pos_weight': 11.69187081625974}. Best is trial 36 with value: 0.14974468219527162.
# [I 2024-04-10 21:48:36,843] Trial 39 finished with value: 0.14981890432022485 and parameters: {'n_estimators': 2580, 'learning_rate': 0.03259181554208129, 'min_child_weight': 2, 'max_depth': 24, 'max_delta_step': 7, 'subsample': 0.9900769050513573, 'colsample_bytree': 0.3872655151048217, 'colsample_bylevel': 0.27827140206400613, 'reg_lambda': 0.5186710532003346, 'reg_alpha': 20.5297887524464, 'gamma': 0.4700902953531361, 'scale_pos_weight': 2.679892484150837}. Best is trial 36 with value: 0.14974468219527162.
# [I 2024-04-10 21:49:02,781] Trial 40 finished with value: 0.15001994288982515 and parameters: {'n_estimators': 2567, 'learning_rate': 0.034706738043763855, 'min_child_weight': 3, 'max_depth': 23, 'max_delta_step': 10, 'subsample': 0.7645357706832537, 'colsample_bytree': 0.2792111100825563, 'colsample_bylevel': 0.24089285257415724, 'reg_lambda': 0.08326247001494873, 'reg_alpha': 48.59949145087851, 'gamma': 0.4033544639691181, 'scale_pos_weight': 2.6713787622170027}. Best is trial 36 with value: 0.14974468219527162.
# [I 2024-04-10 21:49:34,127] Trial 41 finished with value: 0.15009151515442404 and parameters: {'n_estimators': 2773, 'learning_rate': 0.029496287267284784, 'min_child_weight': 2, 'max_depth': 15, 'max_delta_step': 7, 'subsample': 0.9955627249496288, 'colsample_bytree': 0.3830099969827304, 'colsample_bylevel': 0.2672434021630219, 'reg_lambda': 0.6581545262234795, 'reg_alpha': 19.535998951987395, 'gamma': 0.1938676757376799, 'scale_pos_weight': 8.154374302934045}. Best is trial 36 with value: 0.14974468219527162.
# [I 2024-04-10 21
. Best is trial 36 with value: 0.14974468219527162.
# [I 2024-04-10 21:51:38,328] Trial 48 finished with value: 0.15349976315137917 and parameters: {'n_estimators': 2345, 'learning_rate': 0.03705193246907592, 'min_child_weight': 1, 'max_depth': 16, 'max_delta_step': 12, 'subsample': 0.8302781989518102, 'colsample_bytree': 0.3065908849280807, 'colsample_bylevel': 0.33619252698456703, 'reg_lambda': 0.27730595396895086, 'reg_alpha': 0.013714245996409484, 'gamma': 0.8849964572387645, 'scale_pos_weight': 1.8119850829705513}. Best is trial 36 with value: 0.14974468219527162.
# [I 2024-04-10 21:52:44,434] Trial 49 finished with value: 0.15262623989250282 and parameters: {'n_estimators': 1371, 'learning_rate': 0.01311134770029819, 'min_child_weight': 3, 'max_depth': 24, 'max_delta_step': 10, 'subsample': 0.10030290804522705, 'colsample_bytree': 0.4651844063767418, 'colsample_bylevel': 0.6651794225258718, 'reg_lambda': 1.7476300098825528, 'reg_alpha': 0.2979731436579773, 'gamma': 0.2362687043761695, 'scale_pos_weight': 5.523389574010249}. Best is trial 36 with value: 0.14974468219527162.
# [I 2024-04-10 21:53:09,865] Trial 50 finished with value: 0.1593439505371167 and parameters: {'n_estimators': 2681, 'learning_rate': 0.14270223382535774, 'min_child_weight': 2, 'max_depth': 32, 'max_delta_step': 0, 'subsample': 0.5978670599173883, 'colsample_bytree': 0.16297544477183096, 'colsample_bylevel': 0.28819306369086567, 'reg_lambda': 0.03255678720597957, 'reg_alpha': 36.42564188250123, 'gamma': 0.11752646142160589, 'scale_pos_weight': 19.49274844228594}. Best is trial 36 with value: 0.14974468219527162.
# [I 2024-04-10 21:53:38,121] Trial 51 finished with value: 0.149644298785399 and parameters: {'n_estimators': 2979, 'learning_rate': 0.02731720080410386, 'min_child_weight': 1, 'max_depth': 26, 'max_delta_step': 9, 'subsample': 0.9230008314874367, 'colsample_bytree': 0.525881184795731, 'colsample_bylevel': 0.1874694035585352, 'reg_lambda': 0.4884159172560919, 'reg_alpha': 29.257775507092223, 'gamma': 0.6308955111424368, 'scale_pos_weight': 1.484756638231536}. Best is trial 51 with value: 0.149644298785399.
# [I 2024-04-10 21:54:10,618] Trial 52 finished with value: 0.15051358902518247 and parameters: {'n_estimators': 2571, 'learning_rate': 0.030026271597033964, 'min_child_weight': 1, 'max_depth': 21, 'max_delta_step': 9, 'subsample': 0.7836075327656427, 'colsample_bytree': 0.4265420111458977, 'colsample_bylevel': 0.22296511254906914, 'reg_lambda': 0.44216925666604134, 'reg_alpha': 12.810386519193171, 'gamma': 0.6738755712034977, 'scale_pos_weight': 1.073286486896044}. Best is trial 51 with value: 0.149644298785399.
# [I 2024-04-10 21:54:40,720] Trial 53 finished with value: 0.14964842953345112 and parameters: {'n_estimators': 2873, 'learning_rate': 0.020114790485320357, 'min_child_weight': 2, 'max_depth': 30, 'max_delta_step': 11, 'subsample': 0.6811834375796303, 'colsample_bytree': 0.48812525375566007, 'colsample_bylevel': 0.1573859497423771, 'reg_lambda': 0.9792410548640172, 'reg_alpha': 20.935497874412615, 'gamma': 1.2343945677613666, 'scale_pos_weight': 1.8121040915593971}. Best is trial 51 with value: 0.149644298785399.
# [I 2024-04-10 21:55:14,324] Trial 54 finished with value: 0.14958166766675912 and parameters: {'n_estimators': 3778, 'learning_rate': 0.019585097523635554, 'min_child_weight': 2, 'max_depth': 26, 'max_delta_step': 11, 'subsample': 0.8942612590862815, 'colsample_bytree': 0.5110737413141956, 'colsample_bylevel': 0.15270934245035508, 'reg_lambda': 1.0389240281221888, 'reg_alpha': 19.185324241603144, 'gamma': 1.3078461773351489, 'scale_pos_weight': 5.767356985370681}. Best is trial 54 with value: 0.14958166766675912.
# [I 2024-04-10
. Best is trial 72 with value: 0.14957976948687574.
# [I 2024-04-10 22:09:57,647] Trial 75 finished with value: 0.14989094641503423 and parameters: {'n_estimators': 3713, 'learning_rate': 0.011540321723289873, 'min_child_weight': 2, 'max_depth': 41, 'max_delta_step': 18, 'subsample': 0.18427568569060038, 'colsample_bytree': 0.6418440273475544, 'colsample_bylevel': 0.12754401883796923, 'reg_lambda': 6.825775293965755, 'reg_alpha': 3.4710958775352574, 'gamma': 0.7842217594962254, 'scale_pos_weight': 2.0585196687743563}. Best is trial 72 with value: 0.14957976948687574.
# [I 2024-04-10 22:10:56,792] Trial 76 finished with value: 0.1501290342255514 and parameters: {'n_estimators': 2918, 'learning_rate': 0.010190711825884876, 'min_child_weight': 3, 'max_depth': 36, 'max_delta_step': 20, 'subsample': 0.8002901167345855, 'colsample_bytree': 0.5400591270085101, 'colsample_bylevel': 0.1045735795163404, 'reg_lambda': 1.3677836505458996, 'reg_alpha': 0.03435605051413824, 'gamma': 1.1543810786011828, 'scale_pos_weight': 3.5558178171253396}. Best is trial 72 with value: 0.14957976948687574.
# [I 2024-04-10 22:11:43,973] Trial 77 finished with value: 0.15015483543105101 and parameters: {'n_estimators': 4710, 'learning_rate': 0.022167793313731025, 'min_child_weight': 2, 'max_depth': 39, 'max_delta_step': 19, 'subsample': 0.8518181947893211, 'colsample_bytree': 0.45778311437669356, 'colsample_bylevel': 0.1975219630035722, 'reg_lambda': 0.6345301972017663, 'reg_alpha': 0.18851045029930225, 'gamma': 1.6078624449618235, 'scale_pos_weight': 0.4319930735797312}. Best is trial 72 with value: 0.14957976948687574.
# [I 2024-04-10 22:12:18,559] Trial 78 finished with value: 0.1497918311131058 and parameters: {'n_estimators': 3379, 'learning_rate': 0.014077550425858235, 'min_child_weight': 3, 'max_depth': 32, 'max_delta_step': 18, 'subsample': 0.7601252087170942, 'colsample_bytree': 0.4968620995196234, 'colsample_bylevel': 0.11989203004325373, 'reg_lambda': 4.9980860194341155, 'reg_alpha': 0.2625675842101721, 'gamma': 2.8279838563976347, 'scale_pos_weight': 14.133398756947942}. Best is trial 72 with value: 0.14957976948687574.
# [I 2024-04-10 22:13:06,359] Trial 79 finished with value: 0.15082599634464153 and parameters: {'n_estimators': 3144, 'learning_rate': 0.012432776399660473, 'min_child_weight': 1, 'max_depth': 30, 'max_delta_step': 16, 'subsample': 0.9276582723888094, 'colsample_bytree': 0.4544413818126449, 'colsample_bylevel': 0.1298091334730792, 'reg_lambda': 0.35189445024978455, 'reg_alpha': 0.22375594530304257, 'gamma': 2.023600088165009, 'scale_pos_weight': 423.912273581829}. Best is trial 72 with value: 0.14957976948687574.
# [I 2024-04-10 22:13:36,498] Trial 80 finished with value: 0.15122703785803265 and parameters: {'n_estimators': 4451, 'learning_rate': 0.017788314211392785, 'min_child_weight': 2, 'max_depth': 37, 'max_delta_step': 20, 'subsample': 0.26042178001522215, 'colsample_bytree': 0.6930090850219097, 'colsample_bylevel': 0.1576074732892343, 'reg_lambda': 3.437018718853479, 'reg_alpha': 77.57070416462697, 'gamma': 4.966128348850574, 'scale_pos_weight': 0.2215817486670671}. Best is trial 72 with value: 0.14957976948687574.
# [I 2024-04-10 22:14:20,533] Trial 81 finished with value: 0.1497998749486226 and parameters: {'n_estimators': 4844, 'learning_rate': 0.017011683372473847, 'min_child_weight': 3, 'max_depth': 34, 'max_delta_step': 17, 'subsample': 0.6842882874743134, 'colsample_bytree': 0.5587975330078042, 'colsample_bylevel': 0.13630481928080201, 'reg_lambda': 2.0910694684978233, 'reg_alpha': 0.6631664716545537, 'gamma': 2.331631820656212, 'scale_pos_weight': 0.5675244009865101}. Best is trial 72 with value: 0.14957976948687574.
# [I 2024-04-10 22:14:54,979] Trial 82 finished with value: 0.14968806763987594 and parameters: {'n_estimators': 4974, 'learning_rate': 0.020977362440386685, 'min_child_weight': 5, 'max_depth': 20, 'max_delta_step': 16, 'subsample': 0.8742474669778519, 'colsample_bytree': 0.6109966253924959, 'colsample_bylevel': 0.1085957596414814, 'reg_lambda': 1.534402574966826, 'reg_alpha': 0.38028905456821943, 'gamma': 2.998405647354311, 'scale_pos_weight': 1.4046885923802426}. Best is trial 72 with value: 0.14957976948687574.
# [I 2024-04-10 22:15:27,649] Trial 83 finished with value: 0.14978296099781946 and parameters: {'n_estimators': 4543, 'learning_rate': 0.02185334308383355, 'min_child_weight': 5, 'max_depth': 24, 'max_delta_step': 18, 'subsample': 0.8666622490448417, 'colsample_bytree': 0.626932961126014, 'colsample_bylevel': 0.10972310718986522, 'reg_lambda': 0.5509073797076666, 'reg_alpha': 0.3699400497061433, 'gamma': 3.1111211095994755, 'scale_pos_weight': 1.4369749547856285}. Best is trial 72 with value: 0.14957976948687574.
# [I 2024-04-10 22:15:55,666] Trial 84 finished with value: 0.1539983853069875 and parameters: {'n_estimators': 4995, 'learning_rate': 0.025365350431651234, 'min_child_weight': 6, 'max_depth': 18, 'max_delta_step': 16, 'subsample': 0.7489358252480164, 'colsample_bytree': 0.40958742460313485, 'colsample_bylevel': 0.14251171457232634, 'reg_lambda': 1.3243185357296245, 'reg_alpha': 1.1667329852189297, 'gamma': 91.7952763442542, 'scale_pos_weight': 4.501963487430159}. Best is trial 72 with value: 0.14957976948687574.
# [I 2024-04-10 22:16:27,145] Trial 85 finished with value: 0.1504568210849629 and parameters: {'n_estimators': 4774, 'learning_rate': 0.01406781819806584, 'min_child_weight': 5, 'max_depth': 21, 'max_delta_step': 8, 'subsample': 0.8057307997759098, 'colsample_bytree': 0.6064314491862849, 'colsample_bylevel': 0.10466178546843603, 'reg_lambda': 1.4868687381913837, 'reg_alpha': 52.36884710761034, 'gamma': 7.119830172887386, 'scale_pos_weight': 2.5419406074683755}. Best is trial 72 with value: 0.14957976948687574.
# [I 2024-04-10 22:17:05,269] Trial 86 finished with value: 0.1503132187577399 and parameters: {'n_estimators': 2887, 'learning_rate': 0.019483697713913773, 'min_child_weight': 2, 'max_depth': 29, 'max_delta_step': 15, 'subsample': 0.9390046226416263, 'colsample_bytree': 0.5176315784052731, 'colsample_bylevel': 0.11603282311123356, 'reg_lambda': 0.3543613248136646, 'reg_alpha': 0.3721558815681257, 'gamma': 1.4290714992281848, 'scale_pos_weight': 0.867006733145565}. Best is trial 72 with value: 0.14957976948687574.
# [I 2024-04-10 22:18:46,419] Trial 87 finished with value: 0.1508649922541976 and parameters: {'n_estimators': 4620, 'learning_rate': 0.011315625021306664, 'min_child_weight': 1, 'max_depth': 20, 'max_delta_step': 12, 'subsample': 0.8669297059584704, 'colsample_bytree': 0.5558690610562724, 'colsample_bylevel': 0.17353094349097248, 'reg_lambda': 1.6798353375389776, 'reg_alpha': 0.15965741658237, 'gamma': 0.3125803077507661, 'scale_pos_weight': 8.626000144355299}. Best is trial 72 with value: 0.14957976948687574.
# [I 2024-04-10 22
. Best is trial 72 with value: 0.14957976948687574.
# [I 2024-04-10 22:23:14,515] Trial 95 finished with value: 0.14971154744403264 and parameters: {'n_estimators': 4597, 'learning_rate': 0.023402460931427612, 'min_child_weight': 5, 'max_depth': 31, 'max_delta_step': 17, 'subsample': 0.7260468369686801, 'colsample_bytree': 0.8621230818304085, 'colsample_bylevel': 0.17580725874226463, 'reg_lambda': 12.50209335969377, 'reg_alpha': 1.5262288177219465, 'gamma': 4.925952988860395, 'scale_pos_weight': 1.6541323517956148}. Best is trial 72 with value: 0.14957976948687574.
# [I 2024-04-10 22:23:45,461] Trial 96 finished with value: 0.149688638097132 and parameters: {'n_estimators': 4470, 'learning_rate': 0.026616074154604877, 'min_child_weight': 4, 'max_depth': 32, 'max_delta_step': 15, 'subsample': 0.5865326386078593, 'colsample_bytree': 0.7539549270576441, 'colsample_bylevel': 0.1581577201527368, 'reg_lambda': 10.214192402591875, 'reg_alpha': 0.7360485023710505, 'gamma': 5.9533636122724465, 'scale_pos_weight': 5.055213578742652}. Best is trial 72 with value: 0.14957976948687574.
# [I 2024-04-10 22:24:13,917] Trial 97 finished with value: 0.15007428298382192 and parameters: {'n_estimators': 4435, 'learning_rate': 0.049585714119589404, 'min_child_weight': 5, 'max_depth': 32, 'max_delta_step': 15, 'subsample': 0.5642270201051439, 'colsample_bytree': 0.9384985577517893, 'colsample_bylevel': 0.19269144387542012, 'reg_lambda': 7.338519259167778, 'reg_alpha': 0.7905582376294152, 'gamma': 6.882003199774269, 'scale_pos_weight': 5.431683835098105}. Best is trial 72 with value: 0.14957976948687574.
# [I 2024-04-10 22:24:41,773] Trial 98 finished with value: 0.15084521595133188 and parameters: {'n_estimators': 4670, 'learning_rate': 0.03133699667122551, 'min_child_weight': 4, 'max_depth': 28, 'max_delta_step': 16, 'subsample': 0.6095849406864003, 'colsample_bytree': 0.7599620973160548, 'colsample_bylevel': 0.1592503466883745, 'reg_lambda': 13.210618439522118, 'reg_alpha': 1.1233145879136865, 'gamma': 19.06076664010887, 'scale_pos_weight': 7.138113013145303}. Best is trial 72 with value: 0.14957976948687574.
# [I 2024-04-10 22:25:09,054] Trial 99 finished with value: 0.15001582931864416 and parameters: {'n_estimators': 4179, 'learning_rate': 0.02752088209602214, 'min_child_weight': 4, 'max_depth': 30, 'max_delta_step': 13, 'subsample': 0.5732980895749563, 'colsample_bytree': 0.6829272566720608, 'colsample_bylevel': 0.21093219411140351, 'reg_lambda': 10.76837656397403, 'reg_alpha': 0.672009428898793, 'gamma': 8.918263646321767, 'scale_pos_weight': 11.174484040179975}. Best is trial 72 with value: 0.14957976948687574.
# ----------------------------------------
#
# Best trial: {'n_estimators': 4769, 'learning_rate': 0.011392076355553851, 'min_child_weight': 4, 'max_depth': 34, 'max_delta_step': 19, 'subsample': 0.8628214806010924, 'colsample_bytree': 0.5689835692090704, 'colsample_bylevel': 0.11288211092338911, 'reg_lambda': 6.240021883185795, 'reg_alpha': 0.685239722998817, 'gamma': 2.1791348089595113, 'scale_pos_weight': 1.3762899091614627}
# Best score: 0.14957976948687574
# CPU times: total: 15.4 s
# Wall time: 1h 8min 1s

# %%
best_params = study.best_trial.params
# {'n_estimators': 4769,
#  'learning_rate': 0.011392076355553851,
#  'min_child_weight': 4,
#  'max_depth': 34,
#  'max_delta_step': 19,
#  'subsample': 0.8628214806010924,
#  'colsample_bytree': 0.5689835692090704,
#  'colsample_bylevel': 0.11288211092338911,
#  'reg_lambda': 6.240021883185795,
#  'reg_alpha': 0.685239722998817,
#  'gamma': 2.1791348089595113,
#  'scale_pos_weight': 1.3762899091614627}
best_params
# Out:
# {'n_estimators': 4769,
#  'learning_rate': 0.011392076355553851,
#  'min_child_weight': 4,
#  'max_depth': 34,
#  'max_delta_step': 19,
#  'subsample': 0.8628214806010924,
#  'colsample_bytree': 0.5689835692090704,
#  'colsample_bylevel': 0.11288211092338911,
#  'reg_lambda': 6.240021883185795,
#  'reg_alpha': 0.685239722998817,
#  'gamma': 2.1791348089595113,
#  'scale_pos_weight': 1.3762899091614627}

# %%
best_paramns_xgb = {'n_estimators': 4769,
 'learning_rate': 0.011392076355553851,
 'min_child_weight': 4,
 'max_depth': 34,
 'max_delta_step': 19,
 'subsample': 0.8628214806010924,
 'colsample_bytree': 0.5689835692090704,
 'colsample_bylevel': 0.11288211092338911,
 'reg_lambda': 6.240021883185795,
 'reg_alpha': 0.685239722998817,
 'gamma': 2.1791348089595113,
 'scale_pos_weight': 1.3762899091614627}

# %%
# Initialize XGBoost model with best hyperparameters
model_xgb_tunned = XGBRegressor(random_state=SEED, **best_params)

#fit the model
pipe_xg_tunned = Pipeline([
    ('preprocessor', preprocessor),
    ('model', model_xgb_tunned)
])

pipe_xg_tunned.fit(X, y)
# Out:
# Pipeline(steps=[('preprocessor',
#                  ColumnTransformer(transformers=[('power_transformer',
#                                                   Pipeline(steps=[('power',
#                                                                    PowerTransformer()),
#                                                                   ('scaler',
#                                                                    StandardScaler())]),
#                                                   ['length', 'diameter']),
#                                                  ('sqrt_transformer',
#                                                   Pipeline(steps=[('sqrt',
#                                                                    FunctionTransformer(func=<ufunc 'sqrt'>)),
#                                                                   ('scaler',
#                                                                    StandardScaler())]),
#                                                   ['whole_weight',
#                                                    'shucked_weight',
#                                                    'viscera_weight',
#                                                    's...
#                               grow_policy=None, importance_type=None,
#                               interaction_constraints=None,
#                               learning_rate=0.011392076355553851, max_bin=None,
#                               max_cat_threshold=None, max_cat_to_onehot=None,
#                               max_delta_step=19, max_depth=34, max_leaves=None,
#                               min_child_weight=4, missing=nan,
#                               monotone_constraints=None, multi_strategy=None,
#                               n_estimators=4769, n_jobs=None,
#                               num_parallel_tree=None, random_state=42, ...))])

# %%
# transform the test data 
joblib.dump(pipe_xg_tunned, 'models/xg_tunned.pkl')
# Out:
# ['models/xg_tunned.pkl']

# %% [markdown]
# # Predictions

# %%
#load the model
model = joblib.load('models/xg_tunned.pkl')

# predict on test data
y_pred = model.predict(test)

y_pred[:10]
# Out:
# array([10.016493 ,  9.695518 , 10.00251  , 10.332957 ,  7.736319 ,
#         9.288762 , 10.822373 ,  6.1904197,  7.860931 , 11.262538 ],
#       dtype=float32)

# %%
# Create a DataFrame for the submission data
submission_data = pd.DataFrame(y_pred, index=test.index, columns=['rings'])

submission_data
# Out:
#             rings
# id
# 90615   10.016493
# 90616    9.695518
# 90617   10.002510
# 90618   10.332957
# 90619    7.736319
# ...           ...
# 151021   6.479017
# 151022   9.280291
# 151023  12.085831
# 151024  13.681988
# 151025   8.431396
#
# [60411 rows x 1 columns]

# %%
# Save the DataFrame to a CSV file

submission_data
submission_data.to_csv('outputs/submission_xgb_best_transformations.csv')

# %% [markdown]
# kagge public result was: `0.14821`

# %% [markdown]
# # stuff to do

# %% [markdown]
# - optimize for catboost, lightgb
# - voting
# - emsemble
# - add more features
# - conversion to log(y)
