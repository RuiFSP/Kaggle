# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
import optuna
import joblib
import shap

# STATISTICS
from statsmodels.graphics.gofplots import qqplot

# HYPOTHESIS TESTING
from scipy.stats import ks_2samp

# Sklearn preprocessing
from sklearn.model_selection import cross_val_score, KFold, RandomizedSearchCV, train_test_split, GridSearchCV, StratifiedKFold, StratifiedShuffleSplit
from sklearn.preprocessing import MinMaxScaler, StandardScaler, RobustScaler, OneHotEncoder, PolynomialFeatures
from sklearn.pipeline import Pipeline, FeatureUnion
from sklearn.compose import ColumnTransformer
from sklearn.svm import SVR
from sklearn.linear_model import LinearRegression, Lasso, Ridge, ElasticNet
from sklearn.ensemble import AdaBoostRegressor,StackingRegressor,RandomForestRegressor, GradientBoostingRegressor, VotingRegressor, HistGradientBoostingRegressor, ExtraTreesRegressor
from sklearn.metrics import make_scorer, mean_squared_error, mean_squared_log_error
from sklearn.feature_selection import SelectKBest, f_regression, mutual_info_regression
from sklearn.inspection import permutation_importance
from xgboost import XGBRegressor
from lightgbm import LGBMRegressor
from catboost import CatBoostRegressor
from sklearn.neighbors import KNeighborsRegressor
from sklearn.kernel_approximation import Nystroem

#notebook settings
sns.set_theme(style = 'white', palette = 'colorblind')
pal = sns.color_palette('colorblind')

pd.set_option('display.max_rows', 100)
pd.options.mode.chained_assignment = None
warnings.simplefilter(action='ignore', category=FutureWarning)

SEED = 42

# %%
# Load data
train = pd.read_csv('data/train.csv',index_col=0)
test = pd.read_csv('data/test.csv',index_col=0)
sub = pd.read_csv('data/sample_submission.csv',index_col=0)

# %% [markdown]
# # Understanding Abalone Dataset Features
#
# - Sex: This feature represents the gender of the abalone,categorized as male (M), female (F), or infant (I).
#
# - Length: The length feature denotes the longest measurement of the abalone shell, from the apex to the base, measured in millimeters.
#
# - Diameter: Diameter represents the measurement of the abalone shell perpendicular to its length, also measured in millimeters.
#
# - Height: This feature signifies the height of the abalone shell, measured perpendicular to the plane formed by the length and diameter, in millimeters.
#
# - Whole weight: Whole weight indicates the total weight of the abalone, encompassing both the meat and the shell, measured in grams.
#
# - Whole weight.1 (Shucked weight): This feature represents the weight of the abalone meat only, measured in grams. It indicates the amount of meat extracted from the shell.
#
# - Whole weight.2 (Viscera weight): Viscera weight signifies the weight of the abalone gut after bleeding, measured in grams.It provides insights into the weight of the internal organs of the abalone.
#
# - Shell weight: This feature represents the weight of the abalone shell only, excluding the meat, measured in grams. It provides insights into the weight distribution between the shell and the edible portion of the abalone.
#
# - Rings: Rings signify the number of rings present on the abalone shell, serving as an indicator of the abalone's age.

# %%
train.head()
# Out:
#    Sex  Length  Diameter  Height  Whole weight  Whole weight.1  \
# id
# 0    F   0.550     0.430   0.150        0.7715          0.3285
# 1    F   0.630     0.490   0.145        1.1300          0.4580
# 2    I   0.160     0.110   0.025        0.0210          0.0055
# 3    M   0.595     0.475   0.150        0.9145          0.3755
# 4    I   0.555     0.425   0.130        0.7820          0.3695
#
#     Whole weight.2  Shell weight  Rings
# id
# 0           0.1465        0.2400     11
# 1           0.2765        0.3200     11
# 2           0.0030        0.0050      6
# 3           0.2055        0.2500     10
# 4           0.1600        0.1975      9

# %%
test.head()
# Out:
#       Sex  Length  Diameter  Height  Whole weight  Whole weight.1  \
# id
# 90615   M   0.645     0.475   0.155        1.2380          0.6185
# 90616   M   0.580     0.460   0.160        0.9830          0.4785
# 90617   M   0.560     0.420   0.140        0.8395          0.3525
# 90618   M   0.570     0.490   0.145        0.8740          0.3525
# 90619   I   0.415     0.325   0.110        0.3580          0.1575
#
#        Whole weight.2  Shell weight
# id
# 90615          0.3125        0.3005
# 90616          0.2195        0.2750
# 90617          0.1845        0.2405
# 90618          0.1865        0.2350
# 90619          0.0670        0.1050

# %%
def rename_and_lowercase(df):
    df = df.rename(columns = {'Whole weight.1':'shucked weight'})
    df = df.rename(columns = {'Whole weight.2':'viscera weight'})
    df = df.rename(columns=lambda x: x.lower().replace(' ', '_'))
    return df

train = rename_and_lowercase(train)
test = rename_and_lowercase(test)

train.columns, test.columns
# Out:
# (Index(['sex', 'length', 'diameter', 'height', 'whole_weight', 'shucked_weight',
#         'viscera_weight', 'shell_weight', 'rings'],
#        dtype='object'),
#  Index(['sex', 'length', 'diameter', 'height', 'whole_weight', 'shucked_weight',
#         'viscera_weight', 'shell_weight'],
#        dtype='object'))

# %%
def generate_summary_statistics(data):
    summary_table = pd.DataFrame(data.dtypes, columns=['dtypes'])
    summary_table['Missing'] = data.isnull().sum()
    summary_table['Unique'] = data.nunique()
    summary_table['Count'] = data.count()
    summary_table['Duplicated'] = data.duplicated().sum()
    return summary_table

# %%
# summary statistics of train data
generate_summary_statistics(train)
# Out:
#                  dtypes  Missing  Unique  Count  Duplicated
# sex              object        0       3  90615           0
# length          float64        0     157  90615           0
# diameter        float64        0     126  90615           0
# height          float64        0      90  90615           0
# whole_weight    float64        0    3175  90615           0
# shucked_weight  float64        0    1799  90615           0
# viscera_weight  float64        0     979  90615           0
# shell_weight    float64        0    1129  90615           0
# rings             int64        0      28  90615           0

# %%
generate_summary_statistics(test)
# Out:
#                  dtypes  Missing  Unique  Count  Duplicated
# sex              object        0       3  60411           0
# length          float64        0     148  60411           0
# diameter        float64        0     130  60411           0
# height          float64        0      85  60411           0
# whole_weight    float64        0    3037  60411           0
# shucked_weight  float64        0    1747  60411           0
# viscera_weight  float64        0     960  60411           0
# shell_weight    float64        0    1089  60411           0

# %%
# check the distribution of categorical features
categorical_features = train.select_dtypes(include=['object']).copy()

for col in categorical_features.columns:
    print(f'{col} distribution:')
    print(categorical_features[col].value_counts(normalize=True))
    print('\n')
# Out:
# sex distribution:
# sex
# I    0.365204
# M    0.342405
# F    0.292391
# Name: proportion, dtype: float64

# %%
def choose_scaler_for_features(data):
    """
    Choose the appropriate scaler for each feature in a DataFrame.

    Parameters:
    data (DataFrame): DataFrame containing numerical features.

    Returns:
    dict: Dictionary mapping feature names to recommended scalers.
    """

    # Initialize a dictionary to store recommended scalers for each feature
    scalers = {}

    # Loop through each feature
    for feature in data.columns:
        feature_data = data[feature]

        # Fit data with different scalers
        minmax_scaled = MinMaxScaler().fit_transform(feature_data.values.reshape(-1, 1)).flatten()
        standard_scaled = StandardScaler().fit_transform(feature_data.values.reshape(-1, 1)).flatten()
        robust_scaled = RobustScaler().fit_transform(feature_data.values.reshape(-1, 1)).flatten()

        # Perform Kolmogorov-Smirnov test between original and scaled data
        ks_minmax = ks_2samp(feature_data, minmax_scaled).statistic
        ks_standard = ks_2samp(feature_data, standard_scaled).statistic
        ks_robust = ks_2samp(feature_data, robust_scaled).statistic

        # Choose the scaler with the lowest KS statistic
        if ks_minmax <= ks_standard and ks_minmax <= ks_robust:
            scalers[feature] = "minmax"
        elif ks_standard <= ks_minmax and ks_standard <= ks_robust:
            scalers[feature] = "standard"
        else:
            scalers[feature] = "robust"

    return scalers

# %%
X = train.drop('rings', axis=1)
y = train['rings']

# %%
X_num = X.select_dtypes(exclude='object')

# Choose scalers for features
scalers = choose_scaler_for_features(X_num)

print("Recommended scalers for each feature:")
scalers
# Out:
# Recommended scalers for each feature:
# {'length': 'minmax',
#  'diameter': 'standard',
#  'height': 'minmax',
#  'whole_weight': 'standard',
#  'shucked_weight': 'minmax',
#  'viscera_weight': 'minmax',
#  'shell_weight': 'minmax'}

# %%
minmax_list = [key for key, value in scalers.items() if value == 'minmax']
standard_list = [key for key, value in scalers.items() if value == 'standard']
robust_list = [key for key, value in scalers.items() if value == 'robust']

print("Features recommended for MinMaxScaler:", minmax_list)
print("Features recommended for StandardScaler:", standard_list)
print("Features recommended for RobustScaler:", robust_list)
# Out:
# Features recommended for MinMaxScaler: ['length', 'height', 'shucked_weight', 'viscera_weight', 'shell_weight']
# Features recommended for StandardScaler: ['diameter', 'whole_weight']
# Features recommended for RobustScaler: []

# %% [markdown]
# # Feature Selection

# %% [markdown]
# ## Mutual Information

# %%
X_num = X.select_dtypes(exclude='object')   

# Calculate mutual information between each feature and the target
mi = mutual_info_regression(X_num, y, random_state=42)
mi = pd.Series(mi, index=X_num.columns)

# Sort the mutual information values in descending order
mi = mi.sort_values(ascending=False)

# Plot the mutual information values
plt.figure(figsize=(10, 6))
mi.plot.bar();

# %% [markdown]
# ## Correlation

# %%
# correlation matrix
corr = train.select_dtypes(exclude='object').corr()

# Create a mask to hide the upper triangle
mask = np.triu(np.ones_like(corr, dtype=bool))

plt.figure(figsize=(12, 10))
sns.heatmap(corr, annot=True, cmap='coolwarm', fmt=".2f", vmin=-1, vmax=1, center=0, square=True, linewidths=.5, cbar_kws={"shrink": .5}, mask=mask)
plt.title('Correlation Matrix')
plt.show();

# %% [markdown]
# # Preprocessing

# %% [markdown]
# ## Pipeline

# %%
# Preprocessing pipeline for numerical features
numerical_pipeline = Pipeline([
    ('scaler', ColumnTransformer([
        ('minmax', MinMaxScaler(), minmax_list),
        ('standard', StandardScaler(), standard_list),
        ('robust', RobustScaler(), robust_list)
    ])
    )
])

# Preprocessing pipeline for categorical features
categorical_pipeline = Pipeline([
    ('encoder', OneHotEncoder(handle_unknown='ignore'))
])

# Combine numerical and categorical pipelines
preprocessing = ColumnTransformer([
    ('numerical', numerical_pipeline, X_num.columns),
    ('categorical', categorical_pipeline, X.select_dtypes(include='object').columns)
])


preprocessing
# Out:
# ColumnTransformer(transformers=[('numerical',
#                                  Pipeline(steps=[('scaler',
#                                                   ColumnTransformer(transformers=[('minmax',
#                                                                                    MinMaxScaler(),
#                                                                                    ['length',
#                                                                                     'height',
#                                                                                     'shucked_weight',
#                                                                                     'viscera_weight',
#                                                                                     'shell_weight']),
#                                                                                   ('standard',
#                                                                                    StandardScaler(),
#                                                                                    ['diameter',
#                                                                                     'whole_weight']),
#                                                                                   ('robust',
#                                                                                    RobustScaler(),
#                                                                                    [])]))]),
#                                  Index(['length', 'diameter', 'height', 'whole_weight', 'shucked_weight',
#        'viscera_weight', 'shell_weight'],
#       dtype='object')),
#                                 ('categorical',
#                                  Pipeline(steps=[('encoder',
#                                                   OneHotEncoder(handle_unknown='ignore'))]),
#                                  Index(['sex'], dtype='object'))])

# %% [markdown]
# ## Tune Xgboost

# %% [markdown]
# ### Xgboost

# %%
def objective(trial):
    
   # Define the hyperparameters to optimize
   params = {
      'n_estimators' : trial.suggest_int('n_estimators',200,5000),
      'learning_rate' : trial.suggest_loguniform('learning_rate',0.01,1),
      'min_child_weight' : trial.suggest_int('min_child_weight',1,10),
      'max_depth' : trial.suggest_int('max_depth',1,50),
      'max_delta_step' : trial.suggest_int('max_delta_step',0,20),
      'subsample' : trial.suggest_uniform('subsample',0.1,1),
      'colsample_bytree' : trial.suggest_uniform('colsample_bytree',0.1,1),
      'colsample_bylevel' : trial.suggest_uniform('colsample_bylevel',0.1,1),
      'reg_lambda' : trial.suggest_loguniform('reg_lambda',0.01,100),
      'reg_alpha' : trial.suggest_loguniform('reg_alpha',0.01,100),
      'gamma' : trial.suggest_loguniform('gamma',0.01,100),
      'scale_pos_weight' : trial.suggest_loguniform('scale_pos_weight',0.01,500),
   }
   
   # Initialize XGBoost model with suggested hyperparameters
   model = XGBRegressor(**params, random_state=SEED)    
   
   # Create a pipeline with preprocessing and XGBoost model
   xgb_pipe = Pipeline([
      ('preprocessing', preprocessing),
      ('xgboost', model)
   ])
   
   # Cross-validation with 5 folds
   cv = StratifiedKFold(n_splits=5, shuffle=True, random_state=SEED)
   
   # Calculate the cross-validated negative RMSLE score
   scores = -1 * cross_val_score(xgb_pipe,
                                 X,
                                 y,
                                 cv=cv,
                                 scoring='neg_root_mean_squared_log_error',
                                 n_jobs=-1)
   
   return scores.mean()

# %%
# %%time

# # perform hyperparameter optimization with Optuna
study = optuna.create_study(direction='minimize', study_name='xgboost_baseline')
study.optimize(objective, n_trials=100)

print('\n----------------------------------------\n')
print(f'Best trial: {study.best_trial.params}')
print(f'Best score: {study.best_value}')
# Out:
# [I 2024-04-04 18:30:35,204] A new study created in memory with name: xgboost_baseline
# [I 2024-04-04 18:31:22,065] Trial 0 finished with value: 0.15996443872167426 and parameters: {'n_estimators': 4708, 'learning_rate': 0.08756062811366011, 'min_child_weight': 8, 'max_depth': 7, 'max_delta_step': 19, 'subsample': 0.38871171348973377, 'colsample_bytree': 0.6203343563364766, 'colsample_bylevel': 0.49817196733428126, 'reg_lambda': 1.2536151579039478, 'reg_alpha': 0.01323164438325455, 'gamma': 0.886614900546469, 'scale_pos_weight': 0.029668231284355827}. Best is trial 0 with value: 0.15996443872167426.
# [I 2024-04-04 18:33:03,552] Trial 1 finished with value: 0.15718092116369403 and parameters: {'n_estimators': 990, 'learning_rate': 0.036111534715182886, 'min_child_weight': 2, 'max_depth': 21, 'max_delta_step': 11, 'subsample': 0.6202445971559727, 'colsample_bytree': 0.6330371996206791, 'colsample_bylevel': 0.6420025031136096, 'reg_lambda': 0.044786617268990365, 'reg_alpha': 0.040757292811225226, 'gamma': 0.03532414639930769, 'scale_pos_weight': 0.3168052159614057}. Best is trial 1 with value: 0.15718092116369403.
# [I 2024-04-04 18:33:27,403] Trial 2 finished with value: 0.16185848350840182 and parameters: {'n_estimators': 908, 'learning_rate': 0.2232530619091106, 'min_child_weight': 8, 'max_depth': 39, 'max_delta_step': 12, 'subsample': 0.8581986317672289, 'colsample_bytree': 0.9857234137988884, 'colsample_bylevel': 0.8896932105754195, 'reg_lambda': 5.276339071424414, 'reg_alpha': 0.14869287752947918, 'gamma': 0.3293838231170729, 'scale_pos_weight': 0.11031485664100443}. Best is trial 1 with value: 0.15718092116369403.
# [I 2024-04-04 18:33:29,476] Trial 3 finished with value: 0.15435656182033752 and parameters: {'n_estimators': 322, 'learning_rate': 0.3392833838939321, 'min_child_weight': 7, 'max_depth': 21, 'max_delta_step': 4, 'subsample': 0.3035594455880061, 'colsample_bytree': 0.3926789771828484, 'colsample_bylevel': 0.2713365981766075, 'reg_lambda': 84.34594180771109, 'reg_alpha': 2.285354454314963, 'gamma': 21.989591808004754, 'scale_pos_weight': 0.01669481598526685}. Best is trial 3 with value: 0.15435656182033752.
. Best is trial 6 with value: 0.14954839944004744.
# [I 2024-04-04 18:42:24,086] Trial 11 finished with value: 0.1511313674226183 and parameters: {'n_estimators': 2603, 'learning_rate': 0.012125581152207533, 'min_child_weight': 1, 'max_depth': 29, 'max_delta_step': 18, 'subsample': 0.15485581368096824, 'colsample_bytree': 0.8085075682839595, 'colsample_bylevel': 0.1376642933785823, 'reg_lambda': 0.20558003714575476, 'reg_alpha': 17.492146210687164, 'gamma': 3.681437960638421, 'scale_pos_weight': 10.157628575422278}. Best is trial 6 with value: 0.14954839944004744.
# [I 2024-04-04 18:42:53,154] Trial 12 finished with value: 0.15017755300787555 and parameters: {'n_estimators': 2206, 'learning_rate': 0.0127656658103335, 'min_child_weight': 1, 'max_depth': 31, 'max_delta_step': 20, 'subsample': 0.1398460882968354, 'colsample_bytree': 0.8894217110050405, 'colsample_bylevel': 0.3707120837667103, 'reg_lambda': 0.2160937243707164, 'reg_alpha': 8.638410783102767, 'gamma': 3.435508363388027, 'scale_pos_weight': 2.838471867488909}. Best is trial 6 with value: 0.14954839944004744.
# [I 2024-04-04 18:43:05,992] Trial 13 finished with value: 0.1523656032773336 and parameters: {'n_estimators': 2012, 'learning_rate': 0.1449791032958148, 'min_child_weight': 10, 'max_depth': 35, 'max_delta_step': 15, 'subsample': 0.9993587993459787, 'colsample_bytree': 0.9613701061454254, 'colsample_bylevel': 0.38789596540667076, 'reg_lambda': 0.2374816204655297, 'reg_alpha': 5.052190944916831, 'gamma': 2.3626748368247057, 'scale_pos_weight': 3.4113353392922536}. Best is trial 6 with value: 0.14954839944004744.
# [I 2024-04-04 18:43:27,496] Trial 14 finished with value: 0.15205663393244612 and parameters: {'n_estimators': 3768, 'learning_rate': 0.010410247119304432, 'min_child_weight': 10, 'max_depth': 49, 'max_delta_step': 8, 'subsample': 0.5726154572400114, 'colsample_bytree': 0.5291562846353361, 'colsample_bylevel': 0.6575030298311344, 'reg_lambda': 0.03792666836611278, 'reg_alpha': 0.3020829559470366, 'gamma': 73.34912217252835, 'scale_pos_weight': 0.09603417472987869}. Best is trial 6 with value: 0.14954839944004744.
# [I 2024-04-04 18:44:06,540] Trial 15 finished with value: 0.1750792019302541 and parameters: {'n_estimators': 1760, 'learning_rate': 0.08162804098778866, 'min_child_weight': 1, 'max_depth': 14, 'max_delta_step': 14, 'subsample': 0.12352932057383825, 'colsample_bytree': 0.8699008919003407, 'colsample_bylevel': 0.36079761915978886, 'reg_lambda': 0.5192541596084163, 'reg_alpha': 0.48655141643480043, 'gamma': 0.7822825341508435, 'scale_pos_weight': 24.563822852250002}. Best is trial 6 with value: 0.14954839944004744.
# [I 2024-04-04 18:44:27,940] Trial 16 finished with value: 0.1590194079060437 and parameters: {'n_estimators': 3547, 'learning_rate': 0.026218184209200943, 'min_child_weight': 5, 'max_depth': 1, 'max_delta_step': 20, 'subsample': 0.8285324636941258, 'colsample_bytree': 0.5329195566307755, 'colsample_bylevel': 0.7886871297128892, 'reg_lambda': 0.058797345639431474, 'reg_alpha': 2.4073604878283037, 'gamma': 9.997450238459699, 'scale_pos_weight': 0.699426709859644}. Best is trial 6 with value: 0.14954839944004744.
# [I 2024-04-04 18
. Best is trial 6 with value: 0.14954839944004744.
# [I 2024-04-04 18:54:35,668] Trial 37 finished with value: 0.15180610714051168 and parameters: {'n_estimators': 1284, 'learning_rate': 0.015616344998975873, 'min_child_weight': 4, 'max_depth': 42, 'max_delta_step': 20, 'subsample': 0.4467939806641271, 'colsample_bytree': 0.5730666869462238, 'colsample_bylevel': 0.2887840284162802, 'reg_lambda': 0.08271626500337001, 'reg_alpha': 43.959280683716194, 'gamma': 3.533984335334025, 'scale_pos_weight': 0.022060823515616113}. Best is trial 6 with value: 0.14954839944004744.
# [I 2024-04-04 18:54:40,665] Trial 38 finished with value: 0.15043764242855315 and parameters: {'n_estimators': 506, 'learning_rate': 0.0202179917015242, 'min_child_weight': 5, 'max_depth': 46, 'max_delta_step': 12, 'subsample': 0.664889965749077, 'colsample_bytree': 0.8244861726390507, 'colsample_bylevel': 0.3593790826744974, 'reg_lambda': 1.5442064984486457, 'reg_alpha': 15.20007191224147, 'gamma': 14.343604658320867, 'scale_pos_weight': 0.055417630244820375}. Best is trial 6 with value: 0.14954839944004744.
# [I 2024-04-04 18:54:55,876] Trial 39 finished with value: 0.15187070899372826 and parameters: {'n_estimators': 2581, 'learning_rate': 0.01547692324838756, 'min_child_weight': 3, 'max_depth': 39, 'max_delta_step': 19, 'subsample': 0.29668528283927487, 'colsample_bytree': 0.6573025706917436, 'colsample_bylevel': 0.8383485004490763, 'reg_lambda': 9.591018784583262, 'reg_alpha': 96.42395028409966, 'gamma': 35.73189539632189, 'scale_pos_weight': 0.012470022751555423}. Best is trial 6 with value: 0.14954839944004744.
# [I 2024-04-04 18:55:21,160] Trial 40 finished with value: 0.16088644183906275 and parameters: {'n_estimators': 3308, 'learning_rate': 0.029642560090665293, 'min_child_weight': 9, 'max_depth': 37, 'max_delta_step': 17, 'subsample': 0.41863846848379094, 'colsample_bytree': 0.18545868986750064, 'colsample_bylevel': 0.18980252410808293, 'reg_lambda': 0.8158551953591419, 'reg_alpha': 25.357981976463552, 'gamma': 5.918809460791853, 'scale_pos_weight': 0.02334548690438854}. Best is trial 6 with value: 0.14954839944004744.
# [I 2024-04-04 18:55:24,477] Trial 41 finished with value: 0.15127269495583257 and parameters: {'n_estimators': 235, 'learning_rate': 0.020809417719636715, 'min_child_weight': 5, 'max_depth': 48, 'max_delta_step': 12, 'subsample': 0.5273184526119592, 'colsample_bytree': 0.8553107349706177, 'colsample_bylevel': 0.34049282988010265, 'reg_lambda': 1.6692072353138163, 'reg_alpha': 13.27662848028271, 'gamma': 15.910518573705284, 'scale_pos_weight': 0.05244281043970711}. Best is trial 6 with value: 0.14954839944004744.
# [I 2024-04-04 18:55:31,257] Trial 42 finished with value: 0.1497932480737934 and parameters: {'n_estimators': 745, 'learning_rate': 0.021680825927171028, 'min_child_weight': 6, 'max_depth': 46, 'max_delta_step': 9, 'subsample': 0.789823789821157, 'colsample_bytree': 0.8223619688343936, 'colsample_bylevel': 0.38389785209056726, 'reg_lambda': 2.7971158511242966, 'reg_alpha': 27.299840501536803, 'gamma': 10.873686247106214, 'scale_pos_weight': 0.16142472416180562}. Best is trial 6 with value: 0.14954839944004744.
# [I 2024-04-04 18:55:40,929] Trial 43 finished with value: 0.14996079189021086 and parameters: {'n_estimators': 551, 'learning_rate': 0.013127927247124827, 'min_child_weight': 8, 'max_depth': 44, 'max_delta_step': 9, 'subsample': 0.7674633356529663, 'colsample_bytree': 0.7547444594946099, 'colsample_bylevel': 0.3997751490371957, 'reg_lambda': 4.447840129784203, 'reg_alpha': 32.199933471170006, 'gamma': 2.457938370534719, 'scale_pos_weight': 0.15707193777728334}. Best is trial 6 with value: 0.14954839944004744.
# [I 2024-04-04 18
. Best is trial 62 with value: 0.14946348778974267.
# [I 2024-04-04 19:18:09,786] Trial 97 finished with value: 0.150194328533192 and parameters: {'n_estimators': 545, 'learning_rate': 0.06482316769296359, 'min_child_weight': 10, 'max_depth': 12, 'max_delta_step': 6, 'subsample': 0.6428544656038542, 'colsample_bytree': 0.8104215842617701, 'colsample_bylevel': 0.8287025062730159, 'reg_lambda': 93.77972830753454, 'reg_alpha': 23.55371048061929, 'gamma': 0.4480980137552083, 'scale_pos_weight': 0.012916129675545177}. Best is trial 62 with value: 0.14946348778974267.
# [I 2024-04-04 19:18:24,297] Trial 98 finished with value: 0.14981032640042233 and parameters: {'n_estimators': 2095, 'learning_rate': 0.08854889455266793, 'min_child_weight': 10, 'max_depth': 17, 'max_delta_step': 4, 'subsample': 0.9671721397259498, 'colsample_bytree': 0.7673356642963214, 'colsample_bylevel': 0.920141795949296, 'reg_lambda': 59.90418886093843, 'reg_alpha': 32.135033243422924, 'gamma': 1.7588224657464924, 'scale_pos_weight': 0.010178440551030482}. Best is trial 62 with value: 0.14946348778974267.
# [I 2024-04-04 19:18:27,102] Trial 99 finished with value: 0.1517884396343627 and parameters: {'n_estimators': 319, 'learning_rate': 0.036604278141986364, 'min_child_weight': 10, 'max_depth': 4, 'max_delta_step': 7, 'subsample': 0.8725464778785991, 'colsample_bytree': 0.6828541818175827, 'colsample_bylevel': 0.9680324719248169, 'reg_lambda': 51.14379874608665, 'reg_alpha': 16.313858988603926, 'gamma': 4.8802752308416855, 'scale_pos_weight': 0.023591636756055207}. Best is trial 62 with value: 0.14946348778974267.
# ----------------------------------------
#
# Best trial: {'n_estimators': 372, 'learning_rate': 0.01903613935016428, 'min_child_weight': 9, 'max_depth': 43, 'max_delta_step': 7, 'subsample': 0.87190454180243, 'colsample_bytree': 0.6600096859400967, 'colsample_bylevel': 0.753401016123006, 'reg_lambda': 28.407294368827163, 'reg_alpha': 20.233188789192443, 'gamma': 0.3734167181266236, 'scale_pos_weight': 0.07986966903124909}
# Best score: 0.14946348778974267
# CPU times: total: 13.7 s
# Wall time: 47min 51s

# %%
#get study name best params
study_name = study.study_name
print(f'Study name: {study_name}')
best_params = study.best_trial.params
best_params
# Out:
# Study name: xgboost_baseline
# {'n_estimators': 372,
#  'learning_rate': 0.01903613935016428,
#  'min_child_weight': 9,
#  'max_depth': 43,
#  'max_delta_step': 7,
#  'subsample': 0.87190454180243,
#  'colsample_bytree': 0.6600096859400967,
#  'colsample_bylevel': 0.753401016123006,
#  'reg_lambda': 28.407294368827163,
#  'reg_alpha': 20.233188789192443,
#  'gamma': 0.3734167181266236,
#  'scale_pos_weight': 0.07986966903124909}

# %%
best_params_xgboost_baseline = {'n_estimators': 372,
                                'learning_rate': 0.01903613935016428,
                                'min_child_weight': 9,
                                'max_depth': 43,
                                'max_delta_step': 7,
                                'subsample': 0.87190454180243,
                                'colsample_bytree': 0.6600096859400967,
                                'colsample_bylevel': 0.753401016123006,
                                'reg_lambda': 28.407294368827163,
                                'reg_alpha': 20.233188789192443,
                                'gamma': 0.3734167181266236,
                                'scale_pos_weight': 0.07986966903124909}

# %%
def get_folds_rmsle(X, y, model, preprocessing):
    """
    Perform cross-validation with a given model and preprocessing pipeline.

    Parameters:
    X (DataFrame): Features.
    y (Series): Target.
    model: Model to evaluate.
    preprocessing: Preprocessing pipeline.
    n_splits (int): Number of splits for cross-validation.

    Returns:
    list: List of RMSLE scores for each fold.
    """

    # Create an empty list to store the scores
    fold_scores = []

    # Cross-validation with 5 folds
    cv = StratifiedKFold(n_splits=5, shuffle=True, random_state=SEED)

    # Loop through each fold
    for train_index, test_index in cv.split(X, y):

        # Split the data into train and test sets
        X_train, X_test = X.iloc[train_index], X.iloc[test_index]
        y_train, y_test = y.iloc[train_index], y.iloc[test_index]

        # Create a pipeline with preprocessing and XGBoost model
        xgb_pipe = Pipeline([
            ('preprocessing', preprocessing),
            ('xgboost', model)
        ])

        # Fit the model
        xgb_pipe.fit(X_train, y_train)

        # Calculate the negative RMSLE score
        score = mean_squared_log_error(y_test, xgb_pipe.predict(X_test), squared=False)

        # Append the score to the list
        fold_scores.append(score)

    return fold_scores

# %%
# model with best params
model_xgb = XGBRegressor(**best_params_xgboost_baseline, random_state=SEED)

# %%
get_folds_rmsle(X, y, model_xgb, preprocessing)
# Out:
# [0.1493776027752679,
#  0.14998396990240462,
#  0.14977678269237107,
#  0.15022434787290176,
#  0.14795473570576798]

# %%
def get_permutation_importance(X, y, model, preprocessing):
    """
    Calculate the permutation importance of features.

    Parameters:
    X (DataFrame): Features.
    y (Series): Target.
    model: Model to evaluate.
    preprocessing: Preprocessing pipeline.

    Returns:
    DataFrame: Permutation importance values.
    """

    # Create a pipeline with preprocessing and XGBoost model
    xgb_pipe = Pipeline([
        ('preprocessing', preprocessing),
        ('xgboost', model)
    ])

    # Fit the model
    xgb_pipe.fit(X, y)

    # Calculate permutation importance
    perm_importance = permutation_importance(xgb_pipe, X, y, n_repeats=5, random_state=SEED, n_jobs=-1)

    # Store the results in a DataFrame
    perm_importance_df = pd.DataFrame(perm_importance.importances_mean, index=X.columns, columns=['importance'])
    
    # sort the values
    perm_importance_df = perm_importance_df.sort_values(by='importance', ascending=False)
    
    total_importance = perm_importance_df['importance'].sum()
    
    perm_importance_df['importance_percentage_permutation'] = (perm_importance_df['importance'] / total_importance) * 100
    
    # add also accumulated importance
    perm_importance_df['accumulated_importance_permutation'] = perm_importance_df['importance_percentage_permutation'].cumsum()
    
    # drop the importance column
    perm_importance_df = perm_importance_df.drop(columns = 'importance')
    
    # prettify the values by rounding to 4 decimal places and color coding
    perm_importance_df = perm_importance_df.style.format("{:.4f}").background_gradient(cmap='coolwarm', axis=0)

    return perm_importance_df

# %%
permutation_importance_df = get_permutation_importance(X, y, model_xgb, preprocessing)

permutation_importance_df
# Out:
# <style type="text/css">
# #T_f6288_row0_col0, #T_f6288_row7_col1 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_f6288_row0_col1, #T_f6288_row7_col0 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_f6288_row1_col0 {
#   background-color: #f7bca1;
#   color: #000000;
# }
# #T_f6288_row1_col1 {
#   background-color: #cbd8ee;
#   color: #000000;
# }
# #T_f6288_row2_col0 {
#   background-color: #bed2f6;
#   color: #000000;
# }
# #T_f6288_row2_col1 {
#   background-color: #f7aa8c;
#   color: #000000;
# }
# #T_f6288_row3_col0 {
#   background-color: #5f7fe8;
#   color: #f1f1f1;
# }
# #T_f6288_row3_col1 {
#   background-color: #ec8165;
#   color: #f1f1f1;
# }
# #T_f6288_row4_col0 {
#   background-color: #4f69d9;
#   color: #f1f1f1;
# }
# #T_f6288_row4_col1 {
#   background-color: #dd5f4b;
#   color: #f1f1f1;
# }
# #T_f6288_row5_col0 {
#   background-color: #465ecf;
#   color: #f1f1f1;
# }
# #T_f6288_row5_col1 {
#   background-color: #cd423b;
#   color: #f1f1f1;
# }
# #T_f6288_row6_col0 {
#   background-color: #4358cb;
#   color: #f1f1f1;
# }
# #T_f6288_row6_col1 {
#   background-color: #be242e;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_f6288">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_f6288_level0_col0" class="col_heading level0 col0" >importance_percentage_permutation</th>
#       <th id="T_f6288_level0_col1" class="col_heading level0 col1" >accumulated_importance_permutation</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_f6288_level0_row0" class="row_heading level0 row0" >shell_weight</th>
#       <td id="T_f6288_row0_col0" class="data row0 col0" >39.3199</td>
#       <td id="T_f6288_row0_col1" class="data row0 col1" >39.3199</td>
#     </tr>
#     <tr>
#       <th id="T_f6288_level0_row1" class="row_heading level0 row1" >shucked_weight</th>
#       <td id="T_f6288_row1_col0" class="data row1 col0" >26.3404</td>
#       <td id="T_f6288_row1_col1" class="data row1 col1" >65.6603</td>
#     </tr>
#     <tr>
#       <th id="T_f6288_level0_row2" class="row_heading level0 row2" >whole_weight</th>
#       <td id="T_f6288_row2_col0" class="data row2 col0" >16.4696</td>
#       <td id="T_f6288_row2_col1" class="data row2 col1" >82.1299</td>
#     </tr>
#     <tr>
#       <th id="T_f6288_level0_row3" class="row_heading level0 row3" >height</th>
#       <td id="T_f6288_row3_col0" class="data row3 col0" >6.1133</td>
#       <td id="T_f6288_row3_col1" class="data row3 col1" >88.2432</td>
#     </tr>
#     <tr>
#       <th id="T_f6288_level0_row4" class="row_heading level0 row4" >viscera_weight</th>
#       <td id="T_f6288_row4_col0" class="data row4 col0" >4.2320</td>
#       <td id="T_f6288_row4_col1" class="data row4 col1" >92.4752</td>
#     </tr>
#     <tr>
#       <th id="T_f6288_level0_row5" class="row_heading level0 row5" >length</th>
#       <td id="T_f6288_row5_col0" class="data row5 col0" >3.1446</td>
#       <td id="T_f6288_row5_col1" class="data row5 col1" >95.6198</td>
#     </tr>
#     <tr>
#       <th id="T_f6288_level0_row6" class="row_heading level0 row6" >diameter</th>
#       <td id="T_f6288_row6_col0" class="data row6 col0" >2.7136</td>
#       <td id="T_f6288_row6_col1" class="data row6 col1" >98.3334</td>
#     </tr>
#     <tr>
#       <th id="T_f6288_level0_row7" class="row_heading level0 row7" >sex</th>
#       <td id="T_f6288_row7_col0" class="data row7 col0" >1.6666</td>
#       <td id="T_f6288_row7_col1" class="data row7 col1" >100.0000</td>
#     </tr>
#   </tbody>
# </table>

# %%
def get_feature_importance(X, y, model, preprocessing):

    model.fit(preprocessing.fit_transform(X), y)

    # get feature importance
    feature_importance = model.feature_importances_

    # get feature names
    feature_names = list(preprocessing.transformers_[0][1].named_steps['scaler'].get_feature_names_out()) \
        + list(preprocessing.transformers_[1][1].named_steps['encoder'].get_feature_names_out())
        
    # create a DataFrame
    feature_importance_df = pd.DataFrame(feature_importance, index=feature_names, columns=['importance_feature'])

    # sort the values
    feature_importance_df = feature_importance_df.sort_values(by='importance_feature', ascending=False)

    # remove the prefix minmax__, standard__, robust__ from the feature names
    prefixes = ['minmax__', 'standard__', 'robust__']
    for prefix in prefixes:
        feature_importance_df.index = feature_importance_df.index.str.replace(prefix, '')
    
    # prettify the values by rounding to 4 decimal places and color coding
    feature_importance_df = feature_importance_df.style.format("{:.4f}").background_gradient(cmap='coolwarm', axis=0)
    
    # return the feature importance DataFrame
    return feature_importance_df

# %%
feature_importance_df = get_feature_importance(X, y, model_xgb, preprocessing)

feature_importance_df
# Out:
# <style type="text/css">
# #T_57997_row0_col0 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_57997_row1_col0 {
#   background-color: #f29072;
#   color: #f1f1f1;
# }
# #T_57997_row2_col0 {
#   background-color: #b3cdfb;
#   color: #000000;
# }
# #T_57997_row3_col0 {
#   background-color: #a7c5fe;
#   color: #000000;
# }
# #T_57997_row4_col0 {
#   background-color: #7b9ff9;
#   color: #f1f1f1;
# }
# #T_57997_row5_col0 {
#   background-color: #6687ed;
#   color: #f1f1f1;
# }
# #T_57997_row6_col0 {
#   background-color: #5b7ae5;
#   color: #f1f1f1;
# }
# #T_57997_row7_col0 {
#   background-color: #4f69d9;
#   color: #f1f1f1;
# }
# #T_57997_row8_col0 {
#   background-color: #3d50c3;
#   color: #f1f1f1;
# }
# #T_57997_row9_col0 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_57997">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_57997_level0_col0" class="col_heading level0 col0" >importance_feature</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_57997_level0_row0" class="row_heading level0 row0" >shell_weight</th>
#       <td id="T_57997_row0_col0" class="data row0 col0" >0.2946</td>
#     </tr>
#     <tr>
#       <th id="T_57997_level0_row1" class="row_heading level0 row1" >height</th>
#       <td id="T_57997_row1_col0" class="data row1 col0" >0.2308</td>
#     </tr>
#     <tr>
#       <th id="T_57997_level0_row2" class="row_heading level0 row2" >sex_I</th>
#       <td id="T_57997_row2_col0" class="data row2 col0" >0.1179</td>
#     </tr>
#     <tr>
#       <th id="T_57997_level0_row3" class="row_heading level0 row3" >whole_weight</th>
#       <td id="T_57997_row3_col0" class="data row3 col0" >0.1074</td>
#     </tr>
#     <tr>
#       <th id="T_57997_level0_row4" class="row_heading level0 row4" >shucked_weight</th>
#       <td id="T_57997_row4_col0" class="data row4 col0" >0.0729</td>
#     </tr>
#     <tr>
#       <th id="T_57997_level0_row5" class="row_heading level0 row5" >viscera_weight</th>
#       <td id="T_57997_row5_col0" class="data row5 col0" >0.0554</td>
#     </tr>
#     <tr>
#       <th id="T_57997_level0_row6" class="row_heading level0 row6" >diameter</th>
#       <td id="T_57997_row6_col0" class="data row6 col0" >0.0473</td>
#     </tr>
#     <tr>
#       <th id="T_57997_level0_row7" class="row_heading level0 row7" >length</th>
#       <td id="T_57997_row7_col0" class="data row7 col0" >0.0360</td>
#     </tr>
#     <tr>
#       <th id="T_57997_level0_row8" class="row_heading level0 row8" >sex_F</th>
#       <td id="T_57997_row8_col0" class="data row8 col0" >0.0203</td>
#     </tr>
#     <tr>
#       <th id="T_57997_level0_row9" class="row_heading level0 row9" >sex_M</th>
#       <td id="T_57997_row9_col0" class="data row9 col0" >0.0175</td>
#     </tr>
#   </tbody>
# </table>

# %%
# build dataframe with both permutation and feature importance

# get the permutation importance dataframe
perm_df = permutation_importance_df.data

# get the feature importance dataframe
feat_df = feature_importance_df.data

# merge the two dataframes
importance_df = pd.merge(perm_df, feat_df, left_index=True, right_index=True, suffixes=('_perm', '_feat'))

# pretiffy the values
importance_df = importance_df.style.format("{:.4f}").background_gradient(cmap='coolwarm', axis=0)

# display the dataframe
importance_df
# Out:
# <style type="text/css">
# #T_bcc22_row0_col0, #T_bcc22_row0_col2, #T_bcc22_row6_col1 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_bcc22_row0_col1, #T_bcc22_row5_col2, #T_bcc22_row6_col0 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_bcc22_row1_col0 {
#   background-color: #f6bea4;
#   color: #000000;
# }
# #T_bcc22_row1_col1 {
#   background-color: #cedaeb;
#   color: #000000;
# }
# #T_bcc22_row1_col2 {
#   background-color: #6788ee;
#   color: #f1f1f1;
# }
# #T_bcc22_row2_col0 {
#   background-color: #b9d0f9;
#   color: #000000;
# }
# #T_bcc22_row2_col1 {
#   background-color: #f6a385;
#   color: #000000;
# }
# #T_bcc22_row2_col2 {
#   background-color: #96b7ff;
#   color: #000000;
# }
# #T_bcc22_row3_col0 {
#   background-color: #5673e0;
#   color: #f1f1f1;
# }
# #T_bcc22_row3_col1 {
#   background-color: #e8765c;
#   color: #f1f1f1;
# }
# #T_bcc22_row3_col2 {
#   background-color: #f4987a;
#   color: #000000;
# }
# #T_bcc22_row4_col0 {
#   background-color: #465ecf;
#   color: #f1f1f1;
# }
# #T_bcc22_row4_col1 {
#   background-color: #d65244;
#   color: #f1f1f1;
# }
# #T_bcc22_row4_col2 {
#   background-color: #516ddb;
#   color: #f1f1f1;
# }
# #T_bcc22_row5_col0 {
#   background-color: #3e51c5;
#   color: #f1f1f1;
# }
# #T_bcc22_row5_col1 {
#   background-color: #c43032;
#   color: #f1f1f1;
# }
# #T_bcc22_row6_col2 {
#   background-color: #485fd1;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_bcc22">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_bcc22_level0_col0" class="col_heading level0 col0" >importance_percentage_permutation</th>
#       <th id="T_bcc22_level0_col1" class="col_heading level0 col1" >accumulated_importance_permutation</th>
#       <th id="T_bcc22_level0_col2" class="col_heading level0 col2" >importance_feature</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_bcc22_level0_row0" class="row_heading level0 row0" >shell_weight</th>
#       <td id="T_bcc22_row0_col0" class="data row0 col0" >39.3199</td>
#       <td id="T_bcc22_row0_col1" class="data row0 col1" >39.3199</td>
#       <td id="T_bcc22_row0_col2" class="data row0 col2" >0.2946</td>
#     </tr>
#     <tr>
#       <th id="T_bcc22_level0_row1" class="row_heading level0 row1" >shucked_weight</th>
#       <td id="T_bcc22_row1_col0" class="data row1 col0" >26.3404</td>
#       <td id="T_bcc22_row1_col1" class="data row1 col1" >65.6603</td>
#       <td id="T_bcc22_row1_col2" class="data row1 col2" >0.0729</td>
#     </tr>
#     <tr>
#       <th id="T_bcc22_level0_row2" class="row_heading level0 row2" >whole_weight</th>
#       <td id="T_bcc22_row2_col0" class="data row2 col0" >16.4696</td>
#       <td id="T_bcc22_row2_col1" class="data row2 col1" >82.1299</td>
#       <td id="T_bcc22_row2_col2" class="data row2 col2" >0.1074</td>
#     </tr>
#     <tr>
#       <th id="T_bcc22_level0_row3" class="row_heading level0 row3" >height</th>
#       <td id="T_bcc22_row3_col0" class="data row3 col0" >6.1133</td>
#       <td id="T_bcc22_row3_col1" class="data row3 col1" >88.2432</td>
#       <td id="T_bcc22_row3_col2" class="data row3 col2" >0.2308</td>
#     </tr>
#     <tr>
#       <th id="T_bcc22_level0_row4" class="row_heading level0 row4" >viscera_weight</th>
#       <td id="T_bcc22_row4_col0" class="data row4 col0" >4.2320</td>
#       <td id="T_bcc22_row4_col1" class="data row4 col1" >92.4752</td>
#       <td id="T_bcc22_row4_col2" class="data row4 col2" >0.0554</td>
#     </tr>
#     <tr>
#       <th id="T_bcc22_level0_row5" class="row_heading level0 row5" >length</th>
#       <td id="T_bcc22_row5_col0" class="data row5 col0" >3.1446</td>
#       <td id="T_bcc22_row5_col1" class="data row5 col1" >95.6198</td>
#       <td id="T_bcc22_row5_col2" class="data row5 col2" >0.0360</td>
#     </tr>
#     <tr>
#       <th id="T_bcc22_level0_row6" class="row_heading level0 row6" >diameter</th>
#       <td id="T_bcc22_row6_col0" class="data row6 col0" >2.7136</td>
#       <td id="T_bcc22_row6_col1" class="data row6 col1" >98.3334</td>
#       <td id="T_bcc22_row6_col2" class="data row6 col2" >0.0473</td>
#     </tr>
#   </tbody>
# </table>

# %%
#build model with all data
model_xgb.fit(preprocessing.fit_transform(X), y)

# save the model
joblib.dump(model_xgb, 'models/xgboost_base_model.pkl')
# Out:
# ['models/xgboost_base_model.pkl']

# %% [markdown]
# ## Predictions

# %%
# load the model
model = joblib.load('models/xgboost_base_model.pkl')

# transform the test data 
test_transformed = preprocessing.transform(test)

# predict the test data
y_pred_xgb_baseline= model.predict(test_transformed)

y_pred_xgb_baseline[:10]
# Out:
# array([ 9.966673,  9.762585,  9.905755, 10.428654,  7.779489,  9.370717,
#        10.624629,  6.136431,  7.910533, 11.057033], dtype=float32)

# %%
# Create a DataFrame for the submission data
submission_data = pd.DataFrame(y_pred_xgb_baseline, index=test.index, columns=['rings'])

submission_data
# Out:
#             rings
# id
# 90615    9.966673
# 90616    9.762585
# 90617    9.905755
# 90618   10.428654
# 90619    7.779489
# ...           ...
# 151021   6.423208
# 151022   9.335962
# 151023  11.680230
# 151024  13.396136
# 151025   8.645127
#
# [60411 rows x 1 columns]

# %%
train['rings'].value_counts().sort_index()
# Out:
# rings
# 1        25
# 2        29
# 3       386
# 4      1402
# 5      2862
# 6      5411
# 7      9008
# 8     14499
# 9     17465
# 10    12464
# 11     8407
# 12     4719
# 13     4074
# 14     2507
# 15     2072
# 16     1439
# 17     1175
# 18      848
# 19      639
# 20      507
# 21      255
# 22      108
# 23      180
# 24       29
# 25       22
# 26       18
# 27       41
# 29       24
# Name: count, dtype: int64

# %%
# Save the DataFrame to a CSV file

submission_data
submission_data.to_csv('outputs/submission_xgboost_baseline.csv')

# %% [markdown]
# - kagge result with all features - brute force: `0.14816`
